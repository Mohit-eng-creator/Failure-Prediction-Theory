# %% [markdown]
# ### Machine Learning with the Equipment Failure Prediction.

# %% [markdown]
# <h3 style="color:#01308e;">Overview</h3>

# %% [markdown]
# **Now I will take the selected/pre-processed/imputed datasets and feed this into custom ML models by using cross validation.**

# %% [markdown]
# <h3 style="color:#01308e;">Business Problem in machine learning terms:</h3>

# %% [markdown]
# **Given the data points with their respective features, use classification to find out whether the data points belong to surface failure or downhole failure.**

# %% [markdown]
# <h3 style="color:#01308e;">Metric to be used:</h3>

# %% [markdown]
# **F2 Score : ((1 + (2)^2) * Precision * Recall) / (((2)^2 * Precision) + Recall)**

# %% [markdown]
# <h3 style="color:#01308e;">Datasets:</h3>

# %% [markdown]
# **<u>3 datasets :</u><br><br>
# 1)Median imputed Median dataset.<br>
# 2)Median imputed Adasyn dataset.<br>
# 3)Median imputed Smotetomek dataset.<br><br>
# I will feed these 3 datasets into Machine Learning Algorithm.**

# %%
import pickle
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import make_scorer
import warnings
warnings.simplefilter(action="ignore", category=UserWarning)
from sklearn.model_selection import GridSearchCV

# %%
import os
os.cpu_count()
# Out:
# 8

# %% [markdown]
# **Get the data**

# %%
new_standard_train_median_all_features_df=pd.read_pickle("new_standard_train_median_all_features_df.pickle")
y_train_median_all_features=pd.read_pickle("y_train_median_all_features.pickle")
new_standard_test_median_all_features_df=pd.read_pickle("new_standard_test_median_all_features_df.pickle")
y_test_median_all_features=pd.read_pickle("y_test_median_all_features.pickle")

new_x_adasyn_df=pd.read_pickle("new_x_adasyn_df.pickle")
y_adasyn=pd.read_pickle("y_adasyn.pickle")
new_standard_test_adasyn_all_features_df=pd.read_pickle("new_standard_test_adasyn_all_features_df.pickle")
y_test_adasyn_all_features=pd.read_pickle("y_test_adasyn_all_features.pickle")

new_x_smotetomek_df=pd.read_pickle("new_x_smotetomek_df.pickle")
y_smotetomek=pd.read_pickle("y_smotetomek.pickle")
new_standard_test_smotetomek_all_features_df=pd.read_pickle("new_standard_test_smotetomek_all_features_df.pickle")
y_test_smotetomek_all_features=pd.read_pickle("y_test_smotetomek_all_features.pickle")

# %%
y_train_median_all_features.value_counts()
# Out:
# 0.0    47200
# 1.0      800
# Name: target, dtype: int64

# %%
y_test_median_all_features.value_counts()
# Out:
# 0.0    11800
# 1.0      200
# Name: target, dtype: int64

# %% [markdown]
# **Splitting the train set into D1 and D2(50-50)**

# %%
from sklearn.model_selection import train_test_split
D1_median_x_train, D2_median_x_train, D1_median_y_train, D2_median_y_train = \
train_test_split(new_standard_train_median_all_features_df, y_train_median_all_features, test_size=0.50, stratify=y_train_median_all_features)

# %%
D1_median_y_train.value_counts()
# Out:
# 0.0    23600
# 1.0      400
# Name: target, dtype: int64

# %%
D2_median_y_train.value_counts()
# Out:
# 0.0    23600
# 1.0      400
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
D1_adasyn_x_train, D2_adasyn_x_train, D1_adasyn_y_train, D2_adasyn_y_train = train_test_split(new_x_adasyn_df, y_adasyn, test_size=0.50, stratify=y_adasyn)

# %%
D1_adasyn_y_train.value_counts()
# Out:
# 0.0    23600
# 1.0    17696
# Name: target, dtype: int64

# %%
D2_adasyn_y_train.value_counts()
# Out:
# 0.0    23600
# 1.0    17697
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
D1_smotetomek_x_train, D2_smotetomek_x_train, D1_smotetomek_y_train, D2_smotetomek_y_train = train_test_split(new_x_smotetomek_df, y_smotetomek, test_size=0.50, stratify=y_smotetomek)

# %%
D1_smotetomek_y_train.value_counts()
# Out:
# 0.0    23599
# 1.0    17700
# Name: target, dtype: int64

# %%
D2_smotetomek_y_train.value_counts()
# Out:
# 0.0    23600
# 1.0    17699
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# ignoring SettingWithCopyWarning
pd.options.mode.chained_assignment = None
def reset_index(x,y):
    x["target"]=y
    x.reset_index(drop=True, inplace=True)
    y=x.pop("target")
    return x,y

# %%
D1_median_x_train,D1_median_y_train=reset_index(D1_median_x_train,D1_median_y_train)
D2_median_x_train,D2_median_y_train=reset_index(D2_median_x_train,D2_median_y_train)
D1_adasyn_x_train,D1_adasyn_y_train=reset_index(D1_adasyn_x_train,D1_adasyn_y_train)
D2_adasyn_x_train,D2_adasyn_y_train=reset_index(D2_adasyn_x_train,D2_adasyn_y_train)
D1_smotetomek_x_train,D1_smotetomek_y_train=reset_index(D1_smotetomek_x_train,D1_smotetomek_y_train)
D2_smotetomek_x_train,D2_smotetomek_y_train=reset_index(D2_smotetomek_x_train,D2_smotetomek_y_train)

# %%
D1_median_x_train.to_pickle("D1_median_x_train.pickle",protocol=4)
D2_median_x_train.to_pickle("D2_median_x_train.pickle",protocol=4)
D1_median_y_train.to_pickle("D1_median_y_train.pickle",protocol=4)
D2_median_y_train.to_pickle("D2_median_y_train.pickle",protocol=4)

# %%
D1_adasyn_x_train.to_pickle("D1_adasyn_x_train.pickle",protocol=4)
D2_adasyn_x_train.to_pickle("D2_adasyn_x_train.pickle",protocol=4)
D1_adasyn_y_train.to_pickle("D1_adasyn_y_train.pickle",protocol=4)
D2_adasyn_y_train.to_pickle("D2_adasyn_y_train.pickle",protocol=4)

# %%
D1_smotetomek_x_train.to_pickle("D1_smotetomek_x_train.pickle",protocol=4)
D2_smotetomek_x_train.to_pickle("D2_smotetomek_x_train.pickle",protocol=4)
D1_smotetomek_y_train.to_pickle("D1_smotetomek_y_train.pickle",protocol=4)
D2_smotetomek_y_train.to_pickle("D2_smotetomek_y_train.pickle",protocol=4)

# %% [markdown]
# **Now from this D1 do sampling with replacement to create d1,d2,d3....dk(k samples)**

# %% [markdown]
# **I will create model_count samples(hyperparameter). Each sample containing randomly (with replacement), batch_size% of the data(hyperparameter).**

# %% [markdown]
# **First the median data.**

# %%
def run_Decision_Tree(x_train, y_train):
    
    f_2_score = make_scorer(fbeta_score, pos_label=1.0 , beta=2)

    depth_range=[4,6,8,9,10,12,14,17]
    min_samples_range=[2,10,20,30,40,50]

    parameters = {'max_depth': depth_range,'min_samples_split':min_samples_range}
    
    DT=DecisionTreeClassifier(criterion='gini',class_weight="balanced")

    grid = GridSearchCV(DT, parameters, cv=5,n_jobs=-1, scoring=f_2_score)

    grid.fit(x_train, y_train) 

    return grid

# %%
from sklearn.model_selection import train_test_split
def randomly_stratify(x,y,test_size):
    x_remaining,x_batch_D1,y_remaining,y_batch_D1= train_test_split(x,y,test_size=test_size, stratify=y)
    return x_batch_D1,y_batch_D1

# %%
def train_the_decision_trees(x_train,y_train,data_type,i,m_x,b_x):
    
    x_batch,y_batch=randomly_stratify(x_train,y_train,b_x)
    
    x_batch,y_batch=reset_index(x_batch,y_batch)

    b_x=int(b_x*100)
  
    grid=run_Decision_Tree(x_batch,y_batch)

    DT=DecisionTreeClassifier(criterion='gini',class_weight="balanced",max_depth=int(grid.best_params_["max_depth"]),
                              min_samples_split=int(grid.best_params_["min_samples_split"]))
    
    #Fit with train data with the best hyperparameter.
    DT.fit(x_batch,y_batch)

    #Save the trained model
    print("Saving DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+\
                         ".pickle","wb")
    pickle.dump(DT, pickle_object)
    pickle_object.close()
    
    #Save the parameters for this best model
    print("Saving best_params_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)\
          +"_"+str(grid.best_params_))
    pickle_object = open("best_params_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                         str(data_type)+".pickle","wb")
    pickle.dump(grid.best_params_, pickle_object)
    pickle_object.close()

    #Save the best scores for this best model
    print("Saving best_scores_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)\
          +"_"+str(grid.best_score_))
    pickle_object = open("best_score_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                         str(data_type)+".pickle","wb")
    pickle.dump(grid.best_score_, pickle_object)
    pickle_object.close()
    
    #Save the D1 dataset batch given into this model.
    print(f"Saving {b_x} percent data set batch used to train the model {i} out of {m_x}")
    print("Saving x_batch_D1_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    print("Saving y_batch_D1_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    x_batch.to_pickle("x_batch_D1_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                      str(data_type)+".pickle",protocol=4)
    y_batch.to_pickle("x_batch_D1_for_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                      str(data_type)+".pickle",protocol=4)
    
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")    

    return grid.best_params_,grid.best_score_

# %%
model_count=[5,6,7,8,9,10]
batch_size=[0.3,0.4,0.5,0.6,0.7,0.8]

# %%
# %%time
data_type="median_data"
input_list_median_data=[]
param_list_median_data=[]
score_list_median_data=[]
for m_x in model_count:
    for b_x in batch_size:
        for i in range(1,m_x+1):
            param,score=train_the_decision_trees(D1_median_x_train,D1_median_y_train,data_type,i,m_x,b_x)
            input_list_median_data.append("model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_"+data_type)
            param_list_median_data.append(param)
            score_list_median_data.append(score)
# Out:
# Saving DT_model_1_of_5_batch_size_30_percent_median_data
# Saving best_params_for_model_1_of_5_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 40}
# Saving best_scores_for_model_1_of_5_batch_size_30_percent_median_data_0.7350085289925611
# Saving 30 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_30_percent_median_data
# Saving best_params_for_model_2_of_5_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_5_batch_size_30_percent_median_data_0.719288538354936
# Saving 30 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_30_percent_median_data
# Saving best_params_for_model_3_of_5_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_30_percent_median_data_0.742552534654406
# Saving 30 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_30_percent_median_data
# Saving best_params_for_model_4_of_5_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_30_percent_median_data_0.7314368209980676
# Saving 30 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_30_percent_median_data
# Saving best_params_for_model_5_of_5_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 30}
# Saving best_scores_for_model_5_of_5_batch_size_30_percent_median_data_0.7204048579435174
# Saving 30 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_40_percent_median_data
# Saving best_params_for_model_1_of_5_batch_size_40_percent_median_data_{'max_depth': 4, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_5_batch_size_40_percent_median_data_0.7139237703749385
# Saving 40 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_40_percent_median_data
# Saving best_params_for_model_2_of_5_batch_size_40_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_40_percent_median_data_0.807425628375349
# Saving 40 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_40_percent_median_data
# Saving best_params_for_model_3_of_5_batch_size_40_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_5_batch_size_40_percent_median_data_0.7511983870290251
# Saving 40 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_40_percent_median_data
# Saving best_params_for_model_4_of_5_batch_size_40_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_40_percent_median_data_0.7397490499480494
# Saving 40 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_40_percent_median_data
# Saving best_params_for_model_5_of_5_batch_size_40_percent_median_data_{'max_depth': 12, 'min_samples_split': 30}
# Saving best_scores_for_model_5_of_5_batch_size_40_percent_median_data_0.7575451040631306
# Saving 40 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_50_percent_median_data
# Saving best_params_for_model_1_of_5_batch_size_50_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_model_1_of_5_batch_size_50_percent_median_data_0.7690985233773824
# Saving 50 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_50_percent_median_data
# Saving best_params_for_model_2_of_5_batch_size_50_percent_median_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_5_batch_size_50_percent_median_data_0.7564864734083494
# Saving 50 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_50_percent_median_data
# Saving best_params_for_model_3_of_5_batch_size_50_percent_median_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_5_batch_size_50_percent_median_data_0.7980809536981357
# Saving 50 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_50_percent_median_data
# Saving best_params_for_model_4_of_5_batch_size_50_percent_median_data_{'max_depth': 9, 'min_samples_split': 50}
# Saving best_scores_for_model_4_of_5_batch_size_50_percent_median_data_0.7634529635504288
# Saving 50 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_50_percent_median_data
# Saving best_params_for_model_5_of_5_batch_size_50_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_5_of_5_batch_size_50_percent_median_data_0.7775987362289902
# Saving 50 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_60_percent_median_data
# Saving best_params_for_model_1_of_5_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_5_batch_size_60_percent_median_data_0.7775197002587808
# Saving 60 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_60_percent_median_data
# Saving best_params_for_model_2_of_5_batch_size_60_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_5_batch_size_60_percent_median_data_0.7646531810944682
# Saving 60 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_60_percent_median_data
# Saving best_params_for_model_3_of_5_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_60_percent_median_data_0.7677277220628919
# Saving 60 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_60_percent_median_data
# Saving best_params_for_model_4_of_5_batch_size_60_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_4_of_5_batch_size_60_percent_median_data_0.8157967488082264
# Saving 60 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_60_percent_median_data
# Saving best_params_for_model_5_of_5_batch_size_60_percent_median_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_5_batch_size_60_percent_median_data_0.8005900127463684
# Saving 60 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_70_percent_median_data
# Saving best_params_for_model_1_of_5_batch_size_70_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_1_of_5_batch_size_70_percent_median_data_0.8406999064978299
# Saving 70 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_70_percent_median_data
# Saving best_params_for_model_2_of_5_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_5_batch_size_70_percent_median_data_0.7947484023711328
# Saving 70 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_70_percent_median_data
# Saving best_params_for_model_3_of_5_batch_size_70_percent_median_data_{'max_depth': 10, 'min_samples_split': 30}
# Saving best_scores_for_model_3_of_5_batch_size_70_percent_median_data_0.8128890038312454
# Saving 70 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_70_percent_median_data
# Saving best_params_for_model_4_of_5_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_70_percent_median_data_0.7774051501079418
# Saving 70 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_70_percent_median_data
# Saving best_params_for_model_5_of_5_batch_size_70_percent_median_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_5_batch_size_70_percent_median_data_0.832077014691252
# Saving 70 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_80_percent_median_data
# Saving best_params_for_model_1_of_5_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_80_percent_median_data_0.8133976321610323
# Saving 80 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_80_percent_median_data
# Saving best_params_for_model_2_of_5_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_5_batch_size_80_percent_median_data_0.8038136097063283
# Saving 80 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_80_percent_median_data
# Saving best_params_for_model_3_of_5_batch_size_80_percent_median_data_{'max_depth': 10, 'min_samples_split': 20}
# Saving best_scores_for_model_3_of_5_batch_size_80_percent_median_data_0.8258717493791771
# Saving 80 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_80_percent_median_data
# Saving best_params_for_model_4_of_5_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_4_of_5_batch_size_80_percent_median_data_0.8187936003301347
# Saving 80 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_80_percent_median_data
# Saving best_params_for_model_5_of_5_batch_size_80_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_5_of_5_batch_size_80_percent_median_data_0.7850809409076087
# Saving 80 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_30_percent_median_data
# Saving best_params_for_model_1_of_6_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_30_percent_median_data_0.7525724057739037
# Saving 30 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_30_percent_median_data
# Saving best_params_for_model_2_of_6_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_30_percent_median_data_0.7356964108343618
# Saving 30 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_30_percent_median_data
# Saving best_params_for_model_3_of_6_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_30_percent_median_data_0.814603936997971
# Saving 30 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_30_percent_median_data
# Saving best_params_for_model_4_of_6_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_4_of_6_batch_size_30_percent_median_data_0.7600730896067807
# Saving 30 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_30_percent_median_data
# Saving best_params_for_model_5_of_6_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_5_of_6_batch_size_30_percent_median_data_0.7137782153364381
# Saving 30 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_30_percent_median_data
# Saving best_params_for_model_6_of_6_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_30_percent_median_data_0.7161840142955251
# Saving 30 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_40_percent_median_data
# Saving best_params_for_model_1_of_6_batch_size_40_percent_median_data_{'max_depth': 4, 'min_samples_split': 40}
# Saving best_scores_for_model_1_of_6_batch_size_40_percent_median_data_0.7329880321287707
# Saving 40 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_40_percent_median_data
# Saving best_params_for_model_2_of_6_batch_size_40_percent_median_data_{'max_depth': 10, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_6_batch_size_40_percent_median_data_0.7304607017646185
# Saving 40 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_40_percent_median_data
# Saving best_params_for_model_3_of_6_batch_size_40_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_3_of_6_batch_size_40_percent_median_data_0.7527969901434587
# Saving 40 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_40_percent_median_data
# Saving best_params_for_model_4_of_6_batch_size_40_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_model_4_of_6_batch_size_40_percent_median_data_0.8013979921661936
# Saving 40 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_40_percent_median_data
# Saving best_params_for_model_5_of_6_batch_size_40_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_40_percent_median_data_0.7458706402448788
# Saving 40 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_40_percent_median_data
# Saving best_params_for_model_6_of_6_batch_size_40_percent_median_data_{'max_depth': 8, 'min_samples_split': 30}
# Saving best_scores_for_model_6_of_6_batch_size_40_percent_median_data_0.7735847993625298
# Saving 40 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_40_percent_median_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_40_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_50_percent_median_data
# Saving best_params_for_model_1_of_6_batch_size_50_percent_median_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_50_percent_median_data_0.7994491430192635
# Saving 50 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_50_percent_median_data
# Saving best_params_for_model_2_of_6_batch_size_50_percent_median_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_6_batch_size_50_percent_median_data_0.779463047614575
# Saving 50 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_50_percent_median_data
# Saving best_params_for_model_3_of_6_batch_size_50_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_model_3_of_6_batch_size_50_percent_median_data_0.7880765387665736
# Saving 50 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_50_percent_median_data
# Saving best_params_for_model_4_of_6_batch_size_50_percent_median_data_{'max_depth': 4, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_6_batch_size_50_percent_median_data_0.791372440110078
# Saving 50 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_50_percent_median_data
# Saving best_params_for_model_5_of_6_batch_size_50_percent_median_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_6_batch_size_50_percent_median_data_0.7875205911343353
# Saving 50 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_50_percent_median_data
# Saving best_params_for_model_6_of_6_batch_size_50_percent_median_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_50_percent_median_data_0.7730384152969532
# Saving 50 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_50_percent_median_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_50_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_60_percent_median_data
# Saving best_params_for_model_1_of_6_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_1_of_6_batch_size_60_percent_median_data_0.7845705370322682
# Saving 60 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_60_percent_median_data
# Saving best_params_for_model_2_of_6_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_60_percent_median_data_0.7563684157300706
# Saving 60 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_60_percent_median_data
# Saving best_params_for_model_3_of_6_batch_size_60_percent_median_data_{'max_depth': 10, 'min_samples_split': 20}
# Saving best_scores_for_model_3_of_6_batch_size_60_percent_median_data_0.809061411149272
# Saving 60 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_60_percent_median_data
# Saving best_params_for_model_4_of_6_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 30}
# Saving best_scores_for_model_4_of_6_batch_size_60_percent_median_data_0.7970749897820357
# Saving 60 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_60_percent_median_data
# Saving best_params_for_model_5_of_6_batch_size_60_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_5_of_6_batch_size_60_percent_median_data_0.8063725517216451
# Saving 60 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_60_percent_median_data
# Saving best_params_for_model_6_of_6_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 30}
# Saving best_scores_for_model_6_of_6_batch_size_60_percent_median_data_0.7759480880991021
# Saving 60 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_70_percent_median_data
# Saving best_params_for_model_1_of_6_batch_size_70_percent_median_data_{'max_depth': 12, 'min_samples_split': 30}
# Saving best_scores_for_model_1_of_6_batch_size_70_percent_median_data_0.7790024716680394
# Saving 70 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_70_percent_median_data
# Saving best_params_for_model_2_of_6_batch_size_70_percent_median_data_{'max_depth': 12, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_6_batch_size_70_percent_median_data_0.815975945459426
# Saving 70 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_70_percent_median_data
# Saving best_params_for_model_3_of_6_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_6_batch_size_70_percent_median_data_0.8242780495485897
# Saving 70 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_70_percent_median_data
# Saving best_params_for_model_4_of_6_batch_size_70_percent_median_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_70_percent_median_data_0.8213768435738995
# Saving 70 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_70_percent_median_data
# Saving best_params_for_model_5_of_6_batch_size_70_percent_median_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_6_batch_size_70_percent_median_data_0.7998472576259061
# Saving 70 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_70_percent_median_data
# Saving best_params_for_model_6_of_6_batch_size_70_percent_median_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_6_of_6_batch_size_70_percent_median_data_0.823335822002792
# Saving 70 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_80_percent_median_data
# Saving best_params_for_model_1_of_6_batch_size_80_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_1_of_6_batch_size_80_percent_median_data_0.806480660744481
# Saving 80 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_80_percent_median_data
# Saving best_params_for_model_2_of_6_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 30}
# Saving best_scores_for_model_2_of_6_batch_size_80_percent_median_data_0.8160366894104785
# Saving 80 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_80_percent_median_data
# Saving best_params_for_model_3_of_6_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_80_percent_median_data_0.8227735824820677
# Saving 80 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_80_percent_median_data
# Saving best_params_for_model_4_of_6_batch_size_80_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_model_4_of_6_batch_size_80_percent_median_data_0.8213820649297581
# Saving 80 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_80_percent_median_data
# Saving best_params_for_model_5_of_6_batch_size_80_percent_median_data_{'max_depth': 9, 'min_samples_split': 30}
# Saving best_scores_for_model_5_of_6_batch_size_80_percent_median_data_0.831797650157446
# Saving 80 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_80_percent_median_data
# Saving best_params_for_model_6_of_6_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_6_of_6_batch_size_80_percent_median_data_0.8158017362715564
# Saving 80 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_1_of_7_batch_size_30_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_model_1_of_7_batch_size_30_percent_median_data_0.7522697117543846
# Saving 30 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_1_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_2_of_7_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_7_batch_size_30_percent_median_data_0.7228775815928794
# Saving 30 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_2_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_3_of_7_batch_size_30_percent_median_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_30_percent_median_data_0.7573173871191601
# Saving 30 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_3_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_4_of_7_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_7_batch_size_30_percent_median_data_0.7133232525837184
# Saving 30 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_4_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_5_of_7_batch_size_30_percent_median_data_{'max_depth': 4, 'min_samples_split': 30}
# Saving best_scores_for_model_5_of_7_batch_size_30_percent_median_data_0.7237158763148436
# Saving 30 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_5_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_6_of_7_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_7_batch_size_30_percent_median_data_0.7822273365036522
# Saving 30 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_6_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_30_percent_median_data
# Saving best_params_for_model_7_of_7_batch_size_30_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_7_of_7_batch_size_30_percent_median_data_0.7220078163839954
# Saving 30 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_30_percent_median_data
# Saving y_batch_D1_for_model_7_of_7_batch_size_30_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_40_percent_median_data
# ...
# Saving best_params_for_model_7_of_10_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_7_of_10_batch_size_60_percent_median_data_0.7740560883522979
# Saving 60 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_60_percent_median_data
# Saving best_params_for_model_8_of_10_batch_size_60_percent_median_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_8_of_10_batch_size_60_percent_median_data_0.7790718552234124
# Saving 60 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_60_percent_median_data
# Saving best_params_for_model_9_of_10_batch_size_60_percent_median_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_60_percent_median_data_0.7791628116827368
# Saving 60 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_60_percent_median_data
# Saving best_params_for_model_10_of_10_batch_size_60_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_10_of_10_batch_size_60_percent_median_data_0.7851705288164845
# Saving 60 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_60_percent_median_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_60_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_1_of_10_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_10_batch_size_70_percent_median_data_0.7962779180556299
# Saving 70 percent data set batch used to train the model 1 out of 10
# Saving x_batch_D1_for_model_1_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_1_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_2_of_10_batch_size_70_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_10_batch_size_70_percent_median_data_0.8192908757836799
# Saving 70 percent data set batch used to train the model 2 out of 10
# Saving x_batch_D1_for_model_2_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_2_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_3_of_10_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_3_of_10_batch_size_70_percent_median_data_0.8075014318732643
# Saving 70 percent data set batch used to train the model 3 out of 10
# Saving x_batch_D1_for_model_3_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_3_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_4_of_10_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 20}
# Saving best_scores_for_model_4_of_10_batch_size_70_percent_median_data_0.811667434997773
# Saving 70 percent data set batch used to train the model 4 out of 10
# Saving x_batch_D1_for_model_4_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_4_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_5_of_10_batch_size_70_percent_median_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_10_batch_size_70_percent_median_data_0.8065102188234805
# Saving 70 percent data set batch used to train the model 5 out of 10
# Saving x_batch_D1_for_model_5_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_5_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_6_of_10_batch_size_70_percent_median_data_{'max_depth': 8, 'min_samples_split': 40}
# Saving best_scores_for_model_6_of_10_batch_size_70_percent_median_data_0.7816638452717883
# Saving 70 percent data set batch used to train the model 6 out of 10
# Saving x_batch_D1_for_model_6_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_6_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_7_of_10_batch_size_70_percent_median_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_7_of_10_batch_size_70_percent_median_data_0.8124629002202155
# Saving 70 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_8_of_10_batch_size_70_percent_median_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_8_of_10_batch_size_70_percent_median_data_0.8232118501198737
# Saving 70 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_9_of_10_batch_size_70_percent_median_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_9_of_10_batch_size_70_percent_median_data_0.813734541575832
# Saving 70 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_70_percent_median_data
# Saving best_params_for_model_10_of_10_batch_size_70_percent_median_data_{'max_depth': 6, 'min_samples_split': 30}
# Saving best_scores_for_model_10_of_10_batch_size_70_percent_median_data_0.8248579730965131
# Saving 70 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_70_percent_median_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_70_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_1_of_10_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_10_batch_size_80_percent_median_data_0.8052987269501581
# Saving 80 percent data set batch used to train the model 1 out of 10
# Saving x_batch_D1_for_model_1_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_1_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_2_of_10_batch_size_80_percent_median_data_{'max_depth': 10, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_10_batch_size_80_percent_median_data_0.8141645556487942
# Saving 80 percent data set batch used to train the model 2 out of 10
# Saving x_batch_D1_for_model_2_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_2_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_3_of_10_batch_size_80_percent_median_data_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_3_of_10_batch_size_80_percent_median_data_0.8225055569358674
# Saving 80 percent data set batch used to train the model 3 out of 10
# Saving x_batch_D1_for_model_3_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_3_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_4_of_10_batch_size_80_percent_median_data_{'max_depth': 12, 'min_samples_split': 30}
# Saving best_scores_for_model_4_of_10_batch_size_80_percent_median_data_0.8097409949934186
# Saving 80 percent data set batch used to train the model 4 out of 10
# Saving x_batch_D1_for_model_4_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_4_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_5_of_10_batch_size_80_percent_median_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_10_batch_size_80_percent_median_data_0.8171110652039311
# Saving 80 percent data set batch used to train the model 5 out of 10
# Saving x_batch_D1_for_model_5_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_5_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_6_of_10_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_10_batch_size_80_percent_median_data_0.8337162159532043
# Saving 80 percent data set batch used to train the model 6 out of 10
# Saving x_batch_D1_for_model_6_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_6_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_7_of_10_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_10_batch_size_80_percent_median_data_0.8233274533700247
# Saving 80 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_8_of_10_batch_size_80_percent_median_data_{'max_depth': 9, 'min_samples_split': 30}
# Saving best_scores_for_model_8_of_10_batch_size_80_percent_median_data_0.8184392034645682
# Saving 80 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_9_of_10_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_9_of_10_batch_size_80_percent_median_data_0.819785928009334
# Saving 80 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_80_percent_median_data
# Saving best_params_for_model_10_of_10_batch_size_80_percent_median_data_{'max_depth': 12, 'min_samples_split': 20}
# Saving best_scores_for_model_10_of_10_batch_size_80_percent_median_data_0.8155426822189586
# Saving 80 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_80_percent_median_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_80_percent_median_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# CPU times: user 11min 49s, sys: 19.7 s, total: 12min 8s
# Wall time: 2h 44min 32s

# %% [markdown]
# **Take all these models batch wise meaning taking them and run D2 into them to get the result.**

# %%
np.save("input_list_median_data",input_list_median_data)
np.save("param_list_median_data",param_list_median_data)
np.save("score_list_median_data",score_list_median_data)

# %%
input_list_median_data=np.load("input_list_median_data.npy",allow_pickle=True)
param_list_median_data=np.load("param_list_median_data.npy",allow_pickle=True)
score_list_median_data=np.load("score_list_median_data.npy",allow_pickle=True)

# %% [markdown]
# **Selecting only the top 10 dataset and model config to train my Meta model that gives me the highest cv score.**

# %%
# %%time
counter=0
average=[]
models_n_batches=[]
for m_x in model_count:
    for b_x in batch_size:
        b_x=int(b_x*100)
        xxx=0
        val=0
        print("model_count : ",m_x)
        print("batch_size : ",b_x)
        for i in range(0,m_x):
            xxx=xxx+score_list_median_data[counter]
            counter=counter+1
            val=val+1
        print("number of models "+str(m_x)+", batch_size in "+str(b_x),"average : ",xxx/val)
        models_n_batches.append("number of models "+str(m_x)+", batch_size in "+str(b_x))
        average.append(xxx/val)
        print("+++++++++++++++++++++++++++++++++++")
# Out:
# model_count :  5
# batch_size :  30
# number of models 5, batch_size in 30 average :  0.7297382561886976
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  40
# number of models 5, batch_size in 40 average :  0.7539683879580985
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  50
# number of models 5, batch_size in 50 average :  0.7729435300526573
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  60
# number of models 5, batch_size in 60 average :  0.7852574729941472
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  70
# number of models 5, batch_size in 70 average :  0.8115638954998803
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  80
# number of models 5, batch_size in 80 average :  0.8093915064968563
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  30
# number of models 6, batch_size in 30 average :  0.7488180121408301
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  40
# number of models 6, batch_size in 40 average :  0.756183192635075
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  50
# number of models 6, batch_size in 50 average :  0.7864866959902964
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  60
# number of models 6, batch_size in 60 average :  0.7882326655857322
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  70
# number of models 6, batch_size in 70 average :  0.8106360649797755
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  80
# number of models 6, batch_size in 80 average :  0.8190453973326313
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  30
# number of models 7, batch_size in 30 average :  0.7391055660360905
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  40
# number of models 7, batch_size in 40 average :  0.7557962383590048
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  50
# number of models 7, batch_size in 50 average :  0.766133299024692
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  60
# number of models 7, batch_size in 60 average :  0.8005445860647079
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  70
# number of models 7, batch_size in 70 average :  0.8040161165680193
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  80
# number of models 7, batch_size in 80 average :  0.8201136181241908
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  30
# number of models 8, batch_size in 30 average :  0.7334539631588853
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  40
# number of models 8, batch_size in 40 average :  0.7582550264320971
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  50
# number of models 8, batch_size in 50 average :  0.7742555963730868
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  60
# number of models 8, batch_size in 60 average :  0.7897985571993341
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  70
# number of models 8, batch_size in 70 average :  0.8009984533839375
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  80
# number of models 8, batch_size in 80 average :  0.8182726578501313
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  30
# number of models 9, batch_size in 30 average :  0.7621015449763898
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  40
# number of models 9, batch_size in 40 average :  0.7642035398146716
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  50
# number of models 9, batch_size in 50 average :  0.7828504860226436
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  60
# number of models 9, batch_size in 60 average :  0.7845489137038067
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  70
# number of models 9, batch_size in 70 average :  0.8014051296669051
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  80
# number of models 9, batch_size in 80 average :  0.8059276951927564
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  30
# number of models 10, batch_size in 30 average :  0.737137487109728
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  40
# number of models 10, batch_size in 40 average :  0.7756773237895995
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  50
# number of models 10, batch_size in 50 average :  0.7839114056228743
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  60
# number of models 10, batch_size in 60 average :  0.7931541526806706
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  70
# number of models 10, batch_size in 70 average :  0.8097178989818051
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  80
# number of models 10, batch_size in 80 average :  0.817963238274826
# +++++++++++++++++++++++++++++++++++
# CPU times: user 44.1 ms, sys: 12.3 ms, total: 56.5 ms
# Wall time: 42.3 ms

# %% [markdown]
# **Selecting the top 10 train scores and model configurations.**

# %%
np.sort(average)[::-1][:10]
# Out:
# array([0.82011362, 0.8190454 , 0.81827266, 0.81796324, 0.8115639 ,
#        0.81063606, 0.8097179 , 0.80939151, 0.8059277 , 0.80401612])

# %%
np.array(models_n_batches)[np.argsort(average)[::-1][:10]]
# Out:
# array(['number of models 7, batch_size in 80',
#        'number of models 6, batch_size in 80',
#        'number of models 8, batch_size in 80',
#        'number of models 10, batch_size in 80',
#        'number of models 5, batch_size in 70',
#        'number of models 6, batch_size in 70',
#        'number of models 10, batch_size in 70',
#        'number of models 5, batch_size in 80',
#        'number of models 9, batch_size in 80',
#        'number of models 7, batch_size in 70'], dtype='<U37')

# %% [markdown]
# **Now I pass the D2 set to each of these model_count models(hyper parameter), now I will get that many predictions for D2, from each of these models, which in turn will become my new dataset.**

# %%
model_count=[7,6,8,10,5,6,10,5,9,7]
batch_size=[80,80,80,80,70,70,70,80,80,70]

# %%
data_type="median_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    xxx=pd.DataFrame()

    for i in range(1,m_x+1):

        #Load the model.
        pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                             'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Make the prediction.
        y_pred=model.predict(D2_median_x_train)

        #Assign the prediction to a new column in the current dataframe
        xxx[str(i)]=y_pred
        del model

    xxx.to_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
# Out:
# number of models 7, batch_size in 80
# number of models 6, batch_size in 80
# number of models 8, batch_size in 80
# number of models 10, batch_size in 80
# number of models 5, batch_size in 70
# number of models 6, batch_size in 70
# number of models 10, batch_size in 70
# number of models 5, batch_size in 80
# number of models 9, batch_size in 80
# number of models 7, batch_size in 70

# %% [markdown]
# **Now, this new dataset that I have, and the D2_Y values that I have ,I  will train new <u>meta model</u>,
# with 10 configurations. and select the top meta model.**

# %%
def train_the_meta_model(x_data,y_data,data_type,m_x,b_x):
    
    grid=run_Decision_Tree(x_data,y_data)

    Meta_Model=DecisionTreeClassifier(criterion='gini',class_weight="balanced",max_depth=int(grid.best_params_["max_depth"]),
                              min_samples_split=int(grid.best_params_["min_samples_split"]))
    
    #Fit with train data with the best hyperparameter.
    Meta_Model.fit(x_data,y_data)

    #Save the trained model
    print("Saving Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    pickle_object = open("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+\
                         ".pickle","wb")
    pickle.dump(Meta_Model, pickle_object)
    pickle_object.close()
    
    #Save the parameters for this best model
    print("Saving best_params_for_Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)\
          +"_"+str(grid.best_params_))
    pickle_object = open("best_params_for_Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+\
                         ".pickle","wb")
    pickle.dump(grid.best_params_, pickle_object)
    pickle_object.close()

    #Save the best scores for this best model
    print("Saving best_scores_for_Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)\
          +"_"+str(grid.best_score_))
    pickle_object = open("best_scores_for_Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+\
                         ".pickle","wb")
    pickle.dump(grid.best_score_, pickle_object)
    pickle_object.close()
    
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")    

    return grid.best_params_,grid.best_score_

# %%
Meta_Model_input_list_median_data=[]
Meta_Model_param_list_median_data=[]
Meta_Model_score_list_median_data=[]
data_type="median_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))
    x_data=pd.read_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    y_data=D2_median_y_train.copy()
    param,score=train_the_meta_model(x_data,y_data,data_type,m_x,b_x)

    Meta_Model_input_list_median_data.append("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    Meta_Model_param_list_median_data.append(param)
    Meta_Model_score_list_median_data.append(score)
        
np.save("Meta_Model_input_list_median_data.npy",Meta_Model_input_list_median_data)
np.save("Meta_Model_param_list_median_data.npy",Meta_Model_param_list_median_data)
np.save("Meta_Model_score_list_median_data.npy",Meta_Model_score_list_median_data)
Meta_Model_input_list_median_data=np.load("Meta_Model_input_list_median_data.npy",allow_pickle=True)
Meta_Model_param_list_median_data=np.load("Meta_Model_param_list_median_data.npy",allow_pickle=True)
Meta_Model_score_list_median_data=np.load("Meta_Model_score_list_median_data.npy",allow_pickle=True)
# Out:
# number of models 7, batch_size in 80
# Saving Meta_model_7_batch_size_80_percent_median_data
# Saving best_params_for_Meta_model_7_batch_size_80_percent_median_data_{'max_depth': 6, 'min_samples_split': 50}
# Saving best_scores_for_Meta_model_7_batch_size_80_percent_median_data_0.8264799438094151
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 6, batch_size in 80
# Saving Meta_model_6_batch_size_80_percent_median_data
# Saving best_params_for_Meta_model_6_batch_size_80_percent_median_data_{'max_depth': 6, 'min_samples_split': 30}
# Saving best_scores_for_Meta_model_6_batch_size_80_percent_median_data_0.8029906559274667
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 8, batch_size in 80
# Saving Meta_model_8_batch_size_80_percent_median_data
# Saving best_params_for_Meta_model_8_batch_size_80_percent_median_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_Meta_model_8_batch_size_80_percent_median_data_0.8428917231695474
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 10, batch_size in 80
# Saving Meta_model_10_batch_size_80_percent_median_data
# Saving best_params_for_Meta_model_10_batch_size_80_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_Meta_model_10_batch_size_80_percent_median_data_0.8257837412802923
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 5, batch_size in 70
# Saving Meta_model_5_batch_size_70_percent_median_data
# Saving best_params_for_Meta_model_5_batch_size_70_percent_median_data_{'max_depth': 6, 'min_samples_split': 50}
# Saving best_scores_for_Meta_model_5_batch_size_70_percent_median_data_0.8003735444452194
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 6, batch_size in 70
# Saving Meta_model_6_batch_size_70_percent_median_data
# Saving best_params_for_Meta_model_6_batch_size_70_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_6_batch_size_70_percent_median_data_0.800393048615026
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 10, batch_size in 70
# Saving Meta_model_10_batch_size_70_percent_median_data
# Saving best_params_for_Meta_model_10_batch_size_70_percent_median_data_{'max_depth': 17, 'min_samples_split': 20}
# Saving best_scores_for_Meta_model_10_batch_size_70_percent_median_data_0.823574988782768
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 5, batch_size in 80
# Saving Meta_model_5_batch_size_80_percent_median_data
# Saving best_params_for_Meta_model_5_batch_size_80_percent_median_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_5_batch_size_80_percent_median_data_0.8102623564104838
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 9, batch_size in 80
# Saving Meta_model_9_batch_size_80_percent_median_data
# Saving best_params_for_Meta_model_9_batch_size_80_percent_median_data_{'max_depth': 9, 'min_samples_split': 20}
# Saving best_scores_for_Meta_model_9_batch_size_80_percent_median_data_0.8437671260841612
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 70
# Saving Meta_model_7_batch_size_70_percent_median_data
# Saving best_params_for_Meta_model_7_batch_size_70_percent_median_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_Meta_model_7_batch_size_70_percent_median_data_0.8218114259825052
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# **Selecting the top Meta Model with the best CV scores and model configurations on which the main test data.**

# %%
np.sort(Meta_Model_score_list_median_data)[::-1][0]
# Out:
# 0.8437671260841612

# %%
Meta_Model_input_list_median_data[np.argsort(Meta_Model_score_list_median_data)[::-1][0]]
# Out:
# 'Meta_model_9_batch_size_80_percent_median_data'

# %%
Meta_Model_param_list_median_data[np.argsort(Meta_Model_score_list_median_data)[::-1][0]]
# Out:
# {'max_depth': 9, 'min_samples_split': 20}

# %%
model_count=[9]
batch_size=[80]
for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))
# Out:
# number of models 9, batch_size in 80

# %% [markdown]
# **Passing the test set that I have, to each of the base models with configurations with top 10 scores so that I get "model_count" predictions.**

# %%
model_count=[7,6,8,10,5,6,10,5,9,7]
batch_size=[80,80,80,80,70,70,70,80,80,70]

# %%
data_type="median_data"
for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    xxx=pd.DataFrame()

    for i in range(1,m_x+1):

        #Load the model.
        pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                             str(data_type)+".pickle",'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Make the prediction.
        y_pred=model.predict(new_standard_test_median_all_features_df)

        #Assign the prediction to a new column in the current dataframe
        xxx[str(i)]=y_pred
        del model

    xxx.to_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
# Out:
# number of models 7, batch_size in 80
# number of models 6, batch_size in 80
# number of models 8, batch_size in 80
# number of models 10, batch_size in 80
# number of models 5, batch_size in 70
# number of models 6, batch_size in 70
# number of models 10, batch_size in 70
# number of models 5, batch_size in 80
# number of models 9, batch_size in 80
# number of models 7, batch_size in 70

# %% [markdown]
# **Now I pass this new dataset and pass it to the meta_model to get the final prediction.**

# %%
# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    
    true = pd.Series(Y_true)
    predicted = pd.Series(Y_pred)

    return pd.crosstab(true, predicted, rownames=['True'], colnames=['Predicted'])

# %%
model_count=[9]
batch_size=[80]

# %%
data_type="median_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    #Load the model.
    pickle_object = open("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                         'rb')
    model = pickle.load(pickle_object)
    pickle_object.close()

    #Load the data.
    x_test=pd.read_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    y_test=y_test_median_all_features.copy()

    #Make the prediction.
    y_pred=model.predict(x_test)

    #Now try and figure out the F2 Score.
    f2_score=fbeta_score(y_test, y_pred, pos_label=1.0, beta=2)
    print("f2_score : ",f2_score)
    print("confusion_matrix : \n",confusion_matrix(y_test, y_pred))
# Out:
# number of models 9, batch_size in 80
# f2_score :  0.8175559380378657
# confusion_matrix :
#  Predicted    0.0  1.0
# True
# 0.0        11628  172
# 1.0           10  190

# %% [markdown]
# **Repeat the whole process with Adasyn Data now.**

# %%
model_count=[5,6,7,8,9,10]
batch_size=[0.3,0.4,0.5,0.6,0.7,0.8]

# %%
# %%time
data_type="adasyn_data"
input_list_adasyn_data=[]
param_list_adasyn_data=[]
score_list_adasyn_data=[]
for m_x in model_count:
    for b_x in batch_size:
        for i in range(1,m_x+1):
            param,score=train_the_decision_trees(D1_adasyn_x_train,D1_adasyn_y_train,data_type,i,m_x,b_x)
            input_list_adasyn_data.append("model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_"+data_type)
            param_list_adasyn_data.append(param)
            score_list_adasyn_data.append(score)
# Out:
# Saving DT_model_1_of_5_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_1_of_5_batch_size_30_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_30_percent_adasyn_data_0.9901077677817346
# Saving 30 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_2_of_5_batch_size_30_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_30_percent_adasyn_data_0.9891015763715572
# Saving 30 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_3_of_5_batch_size_30_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_5_batch_size_30_percent_adasyn_data_0.9891715799205274
# Saving 30 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_4_of_5_batch_size_30_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_30_percent_adasyn_data_0.9898157270156132
# Saving 30 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_5_of_5_batch_size_30_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_30_percent_adasyn_data_0.9868795513948674
# Saving 30 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_1_of_5_batch_size_40_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_40_percent_adasyn_data_0.9905010047085379
# Saving 40 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_2_of_5_batch_size_40_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_40_percent_adasyn_data_0.9906725519486704
# Saving 40 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_3_of_5_batch_size_40_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_5_batch_size_40_percent_adasyn_data_0.9918845311472019
# Saving 40 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_4_of_5_batch_size_40_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_40_percent_adasyn_data_0.9904934832118691
# Saving 40 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_5_of_5_batch_size_40_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_40_percent_adasyn_data_0.99036220100776
# Saving 40 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_1_of_5_batch_size_50_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_5_batch_size_50_percent_adasyn_data_0.9908656655874474
# Saving 50 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_2_of_5_batch_size_50_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_5_batch_size_50_percent_adasyn_data_0.9905087728250258
# Saving 50 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_3_of_5_batch_size_50_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_50_percent_adasyn_data_0.9929140250249026
# Saving 50 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_4_of_5_batch_size_50_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_50_percent_adasyn_data_0.992168756245284
# Saving 50 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_5_of_5_batch_size_50_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_50_percent_adasyn_data_0.9910660306412126
# Saving 50 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_1_of_5_batch_size_60_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_60_percent_adasyn_data_0.9925061217257822
# Saving 60 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_2_of_5_batch_size_60_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_60_percent_adasyn_data_0.9937600023198069
# Saving 60 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_3_of_5_batch_size_60_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_60_percent_adasyn_data_0.992520950620872
# Saving 60 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_4_of_5_batch_size_60_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_60_percent_adasyn_data_0.9919176278009008
# Saving 60 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_5_of_5_batch_size_60_percent_adasyn_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_60_percent_adasyn_data_0.9925297844899166
# Saving 60 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_1_of_5_batch_size_70_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_70_percent_adasyn_data_0.9938286436458229
# Saving 70 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_2_of_5_batch_size_70_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_70_percent_adasyn_data_0.9927316655104358
# Saving 70 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_3_of_5_batch_size_70_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_70_percent_adasyn_data_0.9933907883821324
# Saving 70 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_4_of_5_batch_size_70_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_70_percent_adasyn_data_0.9930895728952441
# Saving 70 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_5_of_5_batch_size_70_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_70_percent_adasyn_data_0.9932347543525761
# Saving 70 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_1_of_5_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_5_batch_size_80_percent_adasyn_data_0.9933705029480915
# Saving 80 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_2_of_5_batch_size_80_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_80_percent_adasyn_data_0.9942506479783342
# Saving 80 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_3_of_5_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_80_percent_adasyn_data_0.9942739070156875
# Saving 80 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_4_of_5_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_80_percent_adasyn_data_0.9932330419070651
# Saving 80 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_5_of_5_batch_size_80_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_80_percent_adasyn_data_0.9933904749648983
# Saving 80 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_1_of_6_batch_size_30_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_30_percent_adasyn_data_0.9880037748045922
# Saving 30 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_2_of_6_batch_size_30_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_30_percent_adasyn_data_0.9888762728375398
# Saving 30 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_3_of_6_batch_size_30_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_30_percent_adasyn_data_0.9894318408366566
# Saving 30 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_4_of_6_batch_size_30_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_6_batch_size_30_percent_adasyn_data_0.9892960254211836
# Saving 30 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_5_of_6_batch_size_30_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_30_percent_adasyn_data_0.9897745223303478
# Saving 30 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_6_of_6_batch_size_30_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_30_percent_adasyn_data_0.9891351942232689
# Saving 30 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_1_of_6_batch_size_40_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_40_percent_adasyn_data_0.9902767096745068
# Saving 40 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_2_of_6_batch_size_40_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_40_percent_adasyn_data_0.9901891321821644
# Saving 40 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_3_of_6_batch_size_40_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_40_percent_adasyn_data_0.9887719658755898
# Saving 40 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_4_of_6_batch_size_40_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_40_percent_adasyn_data_0.9906425302086396
# Saving 40 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_5_of_6_batch_size_40_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_40_percent_adasyn_data_0.9915690142499469
# Saving 40 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_40_percent_adasyn_data
# Saving best_params_for_model_6_of_6_batch_size_40_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_40_percent_adasyn_data_0.990559473508997
# Saving 40 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_40_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_40_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_1_of_6_batch_size_50_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_50_percent_adasyn_data_0.992938737973958
# Saving 50 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_2_of_6_batch_size_50_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_50_percent_adasyn_data_0.991543836655573
# Saving 50 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_3_of_6_batch_size_50_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_50_percent_adasyn_data_0.9909798011677113
# Saving 50 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_4_of_6_batch_size_50_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_50_percent_adasyn_data_0.9911375829104528
# Saving 50 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_5_of_6_batch_size_50_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_50_percent_adasyn_data_0.9915188098382185
# Saving 50 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_50_percent_adasyn_data
# Saving best_params_for_model_6_of_6_batch_size_50_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_50_percent_adasyn_data_0.9923767988111459
# Saving 50 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_50_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_50_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_1_of_6_batch_size_60_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_60_percent_adasyn_data_0.9926119767641233
# Saving 60 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_2_of_6_batch_size_60_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_60_percent_adasyn_data_0.9926875781179746
# Saving 60 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_3_of_6_batch_size_60_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_60_percent_adasyn_data_0.9914877711934043
# Saving 60 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_4_of_6_batch_size_60_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_60_percent_adasyn_data_0.9920880853131588
# Saving 60 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_5_of_6_batch_size_60_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_60_percent_adasyn_data_0.9914815948104024
# Saving 60 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_6_of_6_batch_size_60_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_6_of_6_batch_size_60_percent_adasyn_data_0.9925024727828173
# Saving 60 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_1_of_6_batch_size_70_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_70_percent_adasyn_data_0.9930865102109336
# Saving 70 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_2_of_6_batch_size_70_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_70_percent_adasyn_data_0.9928688755063249
# Saving 70 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_3_of_6_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_70_percent_adasyn_data_0.9925074555139393
# Saving 70 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_4_of_6_batch_size_70_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_70_percent_adasyn_data_0.9934291676536459
# Saving 70 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_5_of_6_batch_size_70_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_70_percent_adasyn_data_0.9926999633797541
# Saving 70 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_6_of_6_batch_size_70_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_70_percent_adasyn_data_0.9931372660787738
# Saving 70 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_1_of_6_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_80_percent_adasyn_data_0.9944861452991896
# Saving 80 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_2_of_6_batch_size_80_percent_adasyn_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_80_percent_adasyn_data_0.9942012292768538
# Saving 80 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_3_of_6_batch_size_80_percent_adasyn_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_80_percent_adasyn_data_0.993975396162376
# Saving 80 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_4_of_6_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_6_batch_size_80_percent_adasyn_data_0.9933018617937824
# Saving 80 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_5_of_6_batch_size_80_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_80_percent_adasyn_data_0.9929636200725025
# Saving 80 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_6_of_6_batch_size_80_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_80_percent_adasyn_data_0.9934576434514337
# Saving 80 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_1_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_7_batch_size_30_percent_adasyn_data_0.988446963662609
# Saving 30 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_2_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_7_batch_size_30_percent_adasyn_data_0.988343824060844
# Saving 30 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_3_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_30_percent_adasyn_data_0.990829944183153
# Saving 30 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_4_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_7_batch_size_30_percent_adasyn_data_0.989852396143748
# Saving 30 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_5_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_7_batch_size_30_percent_adasyn_data_0.9877802335822305
# Saving 30 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_6_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_7_batch_size_30_percent_adasyn_data_0.9880841463300658
# Saving 30 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_30_percent_adasyn_data
# Saving best_params_for_model_7_of_7_batch_size_30_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_30_percent_adasyn_data_0.9867748389591433
# Saving 30 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_30_percent_adasyn_data
# Saving y_batch_D1_for_model_7_of_7_batch_size_30_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_40_percent_adasyn_data
# ...
# Saving DT_model_7_of_10_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_7_of_10_batch_size_60_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_10_batch_size_60_percent_adasyn_data_0.9922738312192596
# Saving 60 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_8_of_10_batch_size_60_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_8_of_10_batch_size_60_percent_adasyn_data_0.99195655415954
# Saving 60 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_9_of_10_batch_size_60_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_60_percent_adasyn_data_0.9933089247055653
# Saving 60 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_60_percent_adasyn_data
# Saving best_params_for_model_10_of_10_batch_size_60_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_10_of_10_batch_size_60_percent_adasyn_data_0.9935352617855401
# Saving 60 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_60_percent_adasyn_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_60_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_1_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_10_batch_size_70_percent_adasyn_data_0.9931995279664697
# Saving 70 percent data set batch used to train the model 1 out of 10
# Saving x_batch_D1_for_model_1_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_2_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_10_batch_size_70_percent_adasyn_data_0.9925505183566019
# Saving 70 percent data set batch used to train the model 2 out of 10
# Saving x_batch_D1_for_model_2_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_3_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_10_batch_size_70_percent_adasyn_data_0.9933621073945442
# Saving 70 percent data set batch used to train the model 3 out of 10
# Saving x_batch_D1_for_model_3_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_4_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_10_batch_size_70_percent_adasyn_data_0.9926025015676423
# Saving 70 percent data set batch used to train the model 4 out of 10
# Saving x_batch_D1_for_model_4_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_5_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_10_batch_size_70_percent_adasyn_data_0.9921859104150279
# Saving 70 percent data set batch used to train the model 5 out of 10
# Saving x_batch_D1_for_model_5_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_6_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_10_batch_size_70_percent_adasyn_data_0.9930527749929012
# Saving 70 percent data set batch used to train the model 6 out of 10
# Saving x_batch_D1_for_model_6_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_7_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_10_batch_size_70_percent_adasyn_data_0.9921711577311548
# Saving 70 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_8_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_8_of_10_batch_size_70_percent_adasyn_data_0.9928804429613963
# Saving 70 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_9_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_70_percent_adasyn_data_0.9934746739401483
# Saving 70 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_70_percent_adasyn_data
# Saving best_params_for_model_10_of_10_batch_size_70_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_10_of_10_batch_size_70_percent_adasyn_data_0.9929336489278471
# Saving 70 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_70_percent_adasyn_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_70_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_1_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_10_batch_size_80_percent_adasyn_data_0.9929920015128142
# Saving 80 percent data set batch used to train the model 1 out of 10
# Saving x_batch_D1_for_model_1_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_1_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_2_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_10_batch_size_80_percent_adasyn_data_0.9933775149528763
# Saving 80 percent data set batch used to train the model 2 out of 10
# Saving x_batch_D1_for_model_2_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_2_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_3_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_10_batch_size_80_percent_adasyn_data_0.9931754870230975
# Saving 80 percent data set batch used to train the model 3 out of 10
# Saving x_batch_D1_for_model_3_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_3_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_4_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_10_batch_size_80_percent_adasyn_data_0.9933605030773769
# Saving 80 percent data set batch used to train the model 4 out of 10
# Saving x_batch_D1_for_model_4_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_4_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_5_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_10_batch_size_80_percent_adasyn_data_0.9932606494361338
# Saving 80 percent data set batch used to train the model 5 out of 10
# Saving x_batch_D1_for_model_5_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_5_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_6_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_10_batch_size_80_percent_adasyn_data_0.9946712395492094
# Saving 80 percent data set batch used to train the model 6 out of 10
# Saving x_batch_D1_for_model_6_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_6_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_7_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_10_batch_size_80_percent_adasyn_data_0.9930644749370462
# Saving 80 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_8_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_8_of_10_batch_size_80_percent_adasyn_data_0.9933161181635197
# Saving 80 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_9_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_80_percent_adasyn_data_0.9931887721769895
# Saving 80 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_model_10_of_10_batch_size_80_percent_adasyn_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_10_of_10_batch_size_80_percent_adasyn_data_0.9936514283872189
# Saving 80 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_80_percent_adasyn_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_80_percent_adasyn_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# CPU times: user 35min 44s, sys: 28.2 s, total: 36min 13s
# Wall time: 10h 2s

# %% [markdown]
# **Take all these models batch wise meaning taking them and run D2 into them to get the result.**

# %%
np.save("input_list_adasyn_data",input_list_adasyn_data)
np.save("param_list_adasyn_data",param_list_adasyn_data)
np.save("score_list_adasyn_data",score_list_adasyn_data)

# %%
input_list_adasyn_data=np.load("input_list_adasyn_data.npy",allow_pickle=True)
param_list_adasyn_data=np.load("param_list_adasyn_data.npy",allow_pickle=True)
score_list_adasyn_data=np.load("score_list_adasyn_data.npy",allow_pickle=True)

# %% [markdown]
# **Selecting only the top 10 dataset and model config to train my Meta model that gives me the highest cv score.**

# %%
# %%time
counter=0
average=[]
models_n_batches=[]
for m_x in model_count:
    for b_x in batch_size:
        b_x=int(b_x*100)
        xxx=0
        val=0
        print("model_count : ",m_x)
        print("batch_size : ",b_x)
        for i in range(0,m_x):
            xxx=xxx+score_list_adasyn_data[counter]
            counter=counter+1
            val=val+1
        print("number of models "+str(m_x)+", batch_size in "+str(b_x),"average : ",xxx/val)
        models_n_batches.append("number of models "+str(m_x)+", batch_size in "+str(b_x))
        average.append(xxx/val)
        print("+++++++++++++++++++++++++++++++++++")
# Out:
# model_count :  5
# batch_size :  30
# number of models 5, batch_size in 30 average :  0.98901524049686
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  40
# number of models 5, batch_size in 40 average :  0.9907827544048079
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  50
# number of models 5, batch_size in 50 average :  0.9915046500647744
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  60
# number of models 5, batch_size in 60 average :  0.9926468973914557
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  70
# number of models 5, batch_size in 70 average :  0.9932550849572422
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  80
# number of models 5, batch_size in 80 average :  0.9937037149628154
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  30
# number of models 6, batch_size in 30 average :  0.9890862717422647
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  40
# number of models 6, batch_size in 40 average :  0.9903348042833073
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  50
# number of models 6, batch_size in 50 average :  0.9917492612261767
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  60
# number of models 6, batch_size in 60 average :  0.9921432464969802
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  70
# number of models 6, batch_size in 70 average :  0.9929548730572287
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  80
# number of models 6, batch_size in 80 average :  0.993730982676023
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  30
# number of models 7, batch_size in 30 average :  0.9885874781316849
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  40
# number of models 7, batch_size in 40 average :  0.990347791758622
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  50
# number of models 7, batch_size in 50 average :  0.9914778289133679
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  60
# number of models 7, batch_size in 60 average :  0.9923544946763584
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  70
# number of models 7, batch_size in 70 average :  0.9927733971298263
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  80
# number of models 7, batch_size in 80 average :  0.9934001757088188
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  30
# number of models 8, batch_size in 30 average :  0.9888592757130057
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  40
# number of models 8, batch_size in 40 average :  0.9903900914021903
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  50
# number of models 8, batch_size in 50 average :  0.9915956336745173
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  60
# number of models 8, batch_size in 60 average :  0.9919244079158674
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  70
# number of models 8, batch_size in 70 average :  0.99298217868795
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  80
# number of models 8, batch_size in 80 average :  0.9936270012657235
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  30
# number of models 9, batch_size in 30 average :  0.9889073997037197
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  40
# number of models 9, batch_size in 40 average :  0.9900100826715124
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  50
# number of models 9, batch_size in 50 average :  0.9915627254893623
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  60
# number of models 9, batch_size in 60 average :  0.9921145179131601
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  70
# number of models 9, batch_size in 70 average :  0.9932341722739663
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  80
# number of models 9, batch_size in 80 average :  0.9935813161325987
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  30
# number of models 10, batch_size in 30 average :  0.9890950506856052
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  40
# number of models 10, batch_size in 40 average :  0.9895151491632191
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  50
# number of models 10, batch_size in 50 average :  0.9915722297719636
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  60
# number of models 10, batch_size in 60 average :  0.9921367723485505
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  70
# number of models 10, batch_size in 70 average :  0.9928413264253735
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  80
# number of models 10, batch_size in 80 average :  0.9934058189216282
# +++++++++++++++++++++++++++++++++++
# CPU times: user 15.8 ms, sys: 9.8 ms, total: 25.6 ms
# Wall time: 18.3 ms

# %% [markdown]
# **Selecting the top 10 train scores and model configurations.**

# %%
np.sort(average)[::-1][:10]
# Out:
# array([0.99373098, 0.99370371, 0.993627  , 0.99358132, 0.99340582,
#        0.99340018, 0.99325508, 0.99323417, 0.99298218, 0.99295487])

# %%
np.array(models_n_batches)[np.argsort(average)[::-1][:10]]
# Out:
# array(['number of models 6, batch_size in 80',
#        'number of models 5, batch_size in 80',
#        'number of models 8, batch_size in 80',
#        'number of models 9, batch_size in 80',
#        'number of models 10, batch_size in 80',
#        'number of models 7, batch_size in 80',
#        'number of models 5, batch_size in 70',
#        'number of models 9, batch_size in 70',
#        'number of models 8, batch_size in 70',
#        'number of models 6, batch_size in 70'], dtype='<U37')

# %% [markdown]
# **Now I pass the D2 set to each of these model_count models(hyper parameter), now I will get that many predictions for D2, from each of these models, which in turn will become my new dataset.**

# %%
model_count=[6,5,8,9,10,7,5,9,8,6]
batch_size=[80,80,80,80,80,80,70,70,70,70]

# %%
data_type="adasyn_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    xxx=pd.DataFrame()

    for i in range(1,m_x+1):

        #Load the model.
        pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                             'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Make the prediction.
        y_pred=model.predict(D2_adasyn_x_train)

        #Assign the prediction to a new column in the current dataframe
        xxx[str(i)]=y_pred
        del model

    xxx.to_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
# Out:
# number of models 6, batch_size in 80
# number of models 5, batch_size in 80
# number of models 8, batch_size in 80
# number of models 9, batch_size in 80
# number of models 10, batch_size in 80
# number of models 7, batch_size in 80
# number of models 5, batch_size in 70
# number of models 9, batch_size in 70
# number of models 8, batch_size in 70
# number of models 6, batch_size in 70

# %% [markdown]
# **Now, this new dataset that I have, and the D2_Y values that I have ,I  will train new <u>meta model</u>,
# with 10 configurations. and select the top meta model.**

# %%
Meta_Model_input_list_adasyn_data=[]
Meta_Model_param_list_adasyn_data=[]
Meta_Model_score_list_adasyn_data=[]
data_type="adasyn_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))
    x_data=pd.read_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    y_data=D2_adasyn_y_train.copy()
    param,score=train_the_meta_model(x_data,y_data,data_type,m_x,b_x)

    Meta_Model_input_list_adasyn_data.append("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    Meta_Model_param_list_adasyn_data.append(param)
    Meta_Model_score_list_adasyn_data.append(score)
        
np.save("Meta_Model_input_list_adasyn_data.npy",Meta_Model_input_list_adasyn_data)
np.save("Meta_Model_param_list_adasyn_data.npy",Meta_Model_param_list_adasyn_data)
np.save("Meta_Model_score_list_adasyn_data.npy",Meta_Model_score_list_adasyn_data)
Meta_Model_input_list_adasyn_data=np.load("Meta_Model_input_list_adasyn_data.npy",allow_pickle=True)
Meta_Model_param_list_adasyn_data=np.load("Meta_Model_param_list_adasyn_data.npy",allow_pickle=True)
Meta_Model_score_list_adasyn_data=np.load("Meta_Model_score_list_adasyn_data.npy",allow_pickle=True)
# Out:
# number of models 6, batch_size in 80
# Saving Meta_model_6_batch_size_80_percent_adasyn_data
# Saving best_params_for_Meta_model_6_batch_size_80_percent_adasyn_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_Meta_model_6_batch_size_80_percent_adasyn_data_0.9975046159273775
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 5, batch_size in 80
# Saving Meta_model_5_batch_size_80_percent_adasyn_data
# Saving best_params_for_Meta_model_5_batch_size_80_percent_adasyn_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_Meta_model_5_batch_size_80_percent_adasyn_data_0.996884563842344
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 8, batch_size in 80
# Saving Meta_model_8_batch_size_80_percent_adasyn_data
# Saving best_params_for_Meta_model_8_batch_size_80_percent_adasyn_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_8_batch_size_80_percent_adasyn_data_0.9974820917600224
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 9, batch_size in 80
# Saving Meta_model_9_batch_size_80_percent_adasyn_data
# Saving best_params_for_Meta_model_9_batch_size_80_percent_adasyn_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_9_batch_size_80_percent_adasyn_data_0.9974260043925531
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 10, batch_size in 80
# Saving Meta_model_10_batch_size_80_percent_adasyn_data
# Saving best_params_for_Meta_model_10_batch_size_80_percent_adasyn_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_10_batch_size_80_percent_adasyn_data_0.9978210942805115
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 80
# Saving Meta_model_7_batch_size_80_percent_adasyn_data
# Saving best_params_for_Meta_model_7_batch_size_80_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_80_percent_adasyn_data_0.996793762156026
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 5, batch_size in 70
# Saving Meta_model_5_batch_size_70_percent_adasyn_data
# Saving best_params_for_Meta_model_5_batch_size_70_percent_adasyn_data_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_5_batch_size_70_percent_adasyn_data_0.9968852398177527
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 9, batch_size in 70
# Saving Meta_model_9_batch_size_70_percent_adasyn_data
# Saving best_params_for_Meta_model_9_batch_size_70_percent_adasyn_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_9_batch_size_70_percent_adasyn_data_0.9977757066185211
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 8, batch_size in 70
# Saving Meta_model_8_batch_size_70_percent_adasyn_data
# Saving best_params_for_Meta_model_8_batch_size_70_percent_adasyn_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_8_batch_size_70_percent_adasyn_data_0.9970306162099849
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 6, batch_size in 70
# Saving Meta_model_6_batch_size_70_percent_adasyn_data
# Saving best_params_for_Meta_model_6_batch_size_70_percent_adasyn_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_Meta_model_6_batch_size_70_percent_adasyn_data_0.9967144753187698
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# **Selecting the top Meta Model with the best CV scores and model configurations on which the main test data.**

# %%
np.sort(Meta_Model_score_list_adasyn_data)[::-1][0]
# Out:
# 0.9978210942805115

# %%
Meta_Model_param_list_adasyn_data[np.argsort(Meta_Model_score_list_adasyn_data)[::-1][0]]
# Out:
# {'max_depth': 6, 'min_samples_split': 2}

# %%
Meta_Model_input_list_adasyn_data[np.argsort(Meta_Model_score_list_adasyn_data)[::-1][0]]
# Out:
# 'Meta_model_10_batch_size_80_percent_adasyn_data'

# %%
model_count=[10]
batch_size=[80]
for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))
# Out:
# number of models 10, batch_size in 80

# %% [markdown]
# **Passing the test set that I have, to each of the base models with configurations with top 10 scores so that I get "model_count" predictions.**

# %%
model_count=[6,5,8,9,10,7,5,9,8,6]
batch_size=[80,80,80,80,80,80,70,70,70,70]

# %%
data_type="adasyn_data"
for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    xxx=pd.DataFrame()

    for i in range(1,m_x+1):

        #Load the model.
        pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                             str(data_type)+".pickle",'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Make the prediction.
        y_pred=model.predict(new_standard_test_adasyn_all_features_df)

        #Assign the prediction to a new column in the current dataframe
        xxx[str(i)]=y_pred
        del model

    xxx.to_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
# Out:
# number of models 6, batch_size in 80
# number of models 5, batch_size in 80
# number of models 8, batch_size in 80
# number of models 9, batch_size in 80
# number of models 10, batch_size in 80
# number of models 7, batch_size in 80
# number of models 5, batch_size in 70
# number of models 9, batch_size in 70
# number of models 8, batch_size in 70
# number of models 6, batch_size in 70

# %% [markdown]
# **Now I pass this new dataset and pass it to the meta_model to get the final prediction.**

# %%
model_count=[10]
batch_size=[80]

# %%
data_type="adasyn_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    #Load the model.
    pickle_object = open("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                         'rb')
    model = pickle.load(pickle_object)
    pickle_object.close()

    #Load the data.
    x_test=pd.read_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    y_test=y_test_adasyn_all_features.copy()

    #Make the prediction.
    y_pred=model.predict(x_test)

    #Now try and figure out the F2 Score.
    f2_score=fbeta_score(y_test, y_pred, pos_label=1.0, beta=2)
    print("f2_score : ",f2_score)
    print("confusion_matrix : \n",confusion_matrix(y_test, y_pred))
# Out:
# number of models 10, batch_size in 80
# f2_score :  0.8595988538681949
# confusion_matrix :
#  Predicted    0.0  1.0
# True
# 0.0        11733   67
# 1.0           20  180

# %% [markdown]
# **Repeat the whole process with smotetomek Data now.**

# %%
model_count=[5,6,7,8,9,10]
batch_size=[0.3,0.4,0.5,0.6,0.7,0.8]

# %%
# %%time
data_type="smotetomek_data"
input_list_smotetomek_data=[]
param_list_smotetomek_data=[]
score_list_smotetomek_data=[]
for m_x in model_count:
    for b_x in batch_size:
        for i in range(1,m_x+1):
            param,score=train_the_decision_trees(D1_smotetomek_x_train,D1_smotetomek_y_train,data_type,i,m_x,b_x)
            input_list_smotetomek_data.append("model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_"+data_type)
            param_list_smotetomek_data.append(param)
            score_list_smotetomek_data.append(score)
# Out:
# Saving DT_model_1_of_5_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_1_of_5_batch_size_30_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_30_percent_smotetomek_data_0.9880863209256343
# Saving 30 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_2_of_5_batch_size_30_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_5_batch_size_30_percent_smotetomek_data_0.9903127787538797
# Saving 30 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_3_of_5_batch_size_30_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_30_percent_smotetomek_data_0.990753448485653
# Saving 30 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_4_of_5_batch_size_30_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_30_percent_smotetomek_data_0.989955304764603
# Saving 30 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_5_of_5_batch_size_30_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_30_percent_smotetomek_data_0.9902596787970206
# Saving 30 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_1_of_5_batch_size_40_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_40_percent_smotetomek_data_0.9909761678811737
# Saving 40 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_2_of_5_batch_size_40_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_40_percent_smotetomek_data_0.9923314225358499
# Saving 40 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_3_of_5_batch_size_40_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_5_batch_size_40_percent_smotetomek_data_0.9904954493471129
# Saving 40 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_4_of_5_batch_size_40_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_40_percent_smotetomek_data_0.9921325344344674
# Saving 40 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_5_of_5_batch_size_40_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_40_percent_smotetomek_data_0.9926986507625462
# Saving 40 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_1_of_5_batch_size_50_percent_smotetomek_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_50_percent_smotetomek_data_0.9928227243829667
# Saving 50 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_2_of_5_batch_size_50_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_50_percent_smotetomek_data_0.9920599305351587
# Saving 50 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_3_of_5_batch_size_50_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_50_percent_smotetomek_data_0.991831448608442
# Saving 50 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_4_of_5_batch_size_50_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_50_percent_smotetomek_data_0.9910673766970867
# Saving 50 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_5_of_5_batch_size_50_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_50_percent_smotetomek_data_0.9923293681433225
# Saving 50 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_1_of_5_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_60_percent_smotetomek_data_0.9932516399723577
# Saving 60 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_2_of_5_batch_size_60_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_60_percent_smotetomek_data_0.9924953411379411
# Saving 60 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_3_of_5_batch_size_60_percent_smotetomek_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_60_percent_smotetomek_data_0.9929853866437803
# Saving 60 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_4_of_5_batch_size_60_percent_smotetomek_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_60_percent_smotetomek_data_0.9928153235756847
# Saving 60 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_5_of_5_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_60_percent_smotetomek_data_0.9923686993901949
# Saving 60 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_1_of_5_batch_size_70_percent_smotetomek_data_{'max_depth': 14, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_5_batch_size_70_percent_smotetomek_data_0.9937810586807039
# Saving 70 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_2_of_5_batch_size_70_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_5_batch_size_70_percent_smotetomek_data_0.993087087277841
# Saving 70 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_3_of_5_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_70_percent_smotetomek_data_0.9936797784905993
# Saving 70 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_4_of_5_batch_size_70_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_5_batch_size_70_percent_smotetomek_data_0.9939433784258782
# Saving 70 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_5_of_5_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_70_percent_smotetomek_data_0.9942134557882352
# Saving 70 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_5_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_1_of_5_batch_size_80_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_5_batch_size_80_percent_smotetomek_data_0.9949797181379735
# Saving 80 percent data set batch used to train the model 1 out of 5
# Saving x_batch_D1_for_model_1_of_5_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_5_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_5_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_2_of_5_batch_size_80_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_5_batch_size_80_percent_smotetomek_data_0.9945853956348522
# Saving 80 percent data set batch used to train the model 2 out of 5
# Saving x_batch_D1_for_model_2_of_5_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_5_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_5_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_3_of_5_batch_size_80_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_5_batch_size_80_percent_smotetomek_data_0.9940755633280742
# Saving 80 percent data set batch used to train the model 3 out of 5
# Saving x_batch_D1_for_model_3_of_5_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_5_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_5_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_4_of_5_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_5_batch_size_80_percent_smotetomek_data_0.9942755169808128
# Saving 80 percent data set batch used to train the model 4 out of 5
# Saving x_batch_D1_for_model_4_of_5_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_5_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_5_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_5_of_5_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_5_batch_size_80_percent_smotetomek_data_0.9934423614852423
# Saving 80 percent data set batch used to train the model 5 out of 5
# Saving x_batch_D1_for_model_5_of_5_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_5_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_1_of_6_batch_size_30_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_30_percent_smotetomek_data_0.9898449875152837
# Saving 30 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_2_of_6_batch_size_30_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_30_percent_smotetomek_data_0.990039939108577
# Saving 30 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_3_of_6_batch_size_30_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_30_percent_smotetomek_data_0.9909793660582549
# Saving 30 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_4_of_6_batch_size_30_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_30_percent_smotetomek_data_0.989034255351724
# Saving 30 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_5_of_6_batch_size_30_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_30_percent_smotetomek_data_0.9880338938569329
# Saving 30 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_6_of_6_batch_size_30_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_30_percent_smotetomek_data_0.9885304278282089
# Saving 30 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_1_of_6_batch_size_40_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_40_percent_smotetomek_data_0.9926695511437634
# Saving 40 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_2_of_6_batch_size_40_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_40_percent_smotetomek_data_0.9912294932153081
# Saving 40 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_3_of_6_batch_size_40_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_40_percent_smotetomek_data_0.9920730465186571
# Saving 40 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_4_of_6_batch_size_40_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_40_percent_smotetomek_data_0.9902476780111377
# Saving 40 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_5_of_6_batch_size_40_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_40_percent_smotetomek_data_0.990326445595545
# Saving 40 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_40_percent_smotetomek_data
# Saving best_params_for_model_6_of_6_batch_size_40_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_6_of_6_batch_size_40_percent_smotetomek_data_0.9910839464084971
# Saving 40 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_40_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_40_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_1_of_6_batch_size_50_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_50_percent_smotetomek_data_0.9916720790522238
# Saving 50 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_2_of_6_batch_size_50_percent_smotetomek_data_{'max_depth': 14, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_6_batch_size_50_percent_smotetomek_data_0.9919016774475324
# Saving 50 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_3_of_6_batch_size_50_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_6_batch_size_50_percent_smotetomek_data_0.9923971814443387
# Saving 50 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_4_of_6_batch_size_50_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_6_batch_size_50_percent_smotetomek_data_0.9937980634687225
# Saving 50 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_5_of_6_batch_size_50_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_6_batch_size_50_percent_smotetomek_data_0.9926453470088721
# Saving 50 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_50_percent_smotetomek_data
# Saving best_params_for_model_6_of_6_batch_size_50_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_50_percent_smotetomek_data_0.991535907539564
# Saving 50 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_50_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_50_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_1_of_6_batch_size_60_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_60_percent_smotetomek_data_0.9928576591166495
# Saving 60 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_2_of_6_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_6_batch_size_60_percent_smotetomek_data_0.9929667970369526
# Saving 60 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_3_of_6_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_60_percent_smotetomek_data_0.9924216219895037
# Saving 60 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_4_of_6_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_60_percent_smotetomek_data_0.9938903069301164
# Saving 60 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_5_of_6_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_60_percent_smotetomek_data_0.9940412324445995
# Saving 60 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_6_of_6_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_60_percent_smotetomek_data_0.9927251354774956
# Saving 60 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_1_of_6_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_70_percent_smotetomek_data_0.9938925405174134
# Saving 70 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_2_of_6_batch_size_70_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_6_batch_size_70_percent_smotetomek_data_0.9937333609998248
# Saving 70 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_3_of_6_batch_size_70_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_70_percent_smotetomek_data_0.9938622836954215
# Saving 70 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_4_of_6_batch_size_70_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_6_batch_size_70_percent_smotetomek_data_0.9928473441151839
# Saving 70 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_5_of_6_batch_size_70_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_70_percent_smotetomek_data_0.992295958442368
# Saving 70 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_6_of_6_batch_size_70_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_70_percent_smotetomek_data_0.9948115292942397
# Saving 70 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_1_of_6_batch_size_80_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_6_batch_size_80_percent_smotetomek_data_0.9939522033729051
# Saving 80 percent data set batch used to train the model 1 out of 6
# Saving x_batch_D1_for_model_1_of_6_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_6_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_2_of_6_batch_size_80_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_6_batch_size_80_percent_smotetomek_data_0.9942756860188029
# Saving 80 percent data set batch used to train the model 2 out of 6
# Saving x_batch_D1_for_model_2_of_6_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_6_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_3_of_6_batch_size_80_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_6_batch_size_80_percent_smotetomek_data_0.9943444715656593
# Saving 80 percent data set batch used to train the model 3 out of 6
# Saving x_batch_D1_for_model_3_of_6_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_6_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_4_of_6_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_6_batch_size_80_percent_smotetomek_data_0.9943762070965594
# Saving 80 percent data set batch used to train the model 4 out of 6
# Saving x_batch_D1_for_model_4_of_6_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_6_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_5_of_6_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_6_batch_size_80_percent_smotetomek_data_0.994107625548388
# Saving 80 percent data set batch used to train the model 5 out of 6
# Saving x_batch_D1_for_model_5_of_6_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_6_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_6_of_6_batch_size_80_percent_smotetomek_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_6_batch_size_80_percent_smotetomek_data_0.9942173521027661
# Saving 80 percent data set batch used to train the model 6 out of 6
# Saving x_batch_D1_for_model_6_of_6_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_6_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_1_of_7_batch_size_30_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_7_batch_size_30_percent_smotetomek_data_0.9897104394704629
# Saving 30 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_7_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_2_of_7_batch_size_30_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_7_batch_size_30_percent_smotetomek_data_0.9899290372022961
# Saving 30 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_7_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_3_of_7_batch_size_30_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_30_percent_smotetomek_data_0.9901924097558787
# Saving 30 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_7_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_4_of_7_batch_size_30_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_7_batch_size_30_percent_smotetomek_data_0.9901312385543901
# Saving 30 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_7_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_30_percent_smotetomek_data
# Saving best_params_for_model_5_of_7_batch_size_30_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_7_batch_size_30_percent_smotetomek_data_0.9882804509543286
# Saving 30 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_30_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_7_batch_size_30_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ...
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_8_of_10_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_8_of_10_batch_size_60_percent_smotetomek_data_0.9935117649463997
# Saving 60 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_9_of_10_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_60_percent_smotetomek_data_0.9928353626288574
# Saving 60 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_60_percent_smotetomek_data
# Saving best_params_for_model_10_of_10_batch_size_60_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_10_of_10_batch_size_60_percent_smotetomek_data_0.9929900095925678
# Saving 60 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_60_percent_smotetomek_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_60_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_1_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_10_batch_size_70_percent_smotetomek_data_0.9938605090365389
# Saving 70 percent data set batch used to train the model 1 out of 10
# Saving x_batch_D1_for_model_1_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_2_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_10_batch_size_70_percent_smotetomek_data_0.9939859464646806
# Saving 70 percent data set batch used to train the model 2 out of 10
# Saving x_batch_D1_for_model_2_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_3_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_10_batch_size_70_percent_smotetomek_data_0.9946332668719275
# Saving 70 percent data set batch used to train the model 3 out of 10
# Saving x_batch_D1_for_model_3_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_4_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_10_batch_size_70_percent_smotetomek_data_0.9929214715131707
# Saving 70 percent data set batch used to train the model 4 out of 10
# Saving x_batch_D1_for_model_4_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_5_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_10_batch_size_70_percent_smotetomek_data_0.9932453209495818
# Saving 70 percent data set batch used to train the model 5 out of 10
# Saving x_batch_D1_for_model_5_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_6_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_10_batch_size_70_percent_smotetomek_data_0.994376322541461
# Saving 70 percent data set batch used to train the model 6 out of 10
# Saving x_batch_D1_for_model_6_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_7_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_10_batch_size_70_percent_smotetomek_data_0.993489125713851
# Saving 70 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_8_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_8_of_10_batch_size_70_percent_smotetomek_data_0.9936497957894945
# Saving 70 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_9_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_70_percent_smotetomek_data_0.9939078040103031
# Saving 70 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_model_10_of_10_batch_size_70_percent_smotetomek_data_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_10_of_10_batch_size_70_percent_smotetomek_data_0.99364957911831
# Saving 70 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_70_percent_smotetomek_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_70_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_1_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_10_batch_size_80_percent_smotetomek_data_0.9936688658908078
# Saving 80 percent data set batch used to train the model 1 out of 10
# Saving x_batch_D1_for_model_1_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_1_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_2_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_10_batch_size_80_percent_smotetomek_data_0.9941364024104411
# Saving 80 percent data set batch used to train the model 2 out of 10
# Saving x_batch_D1_for_model_2_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_2_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_3_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_10_batch_size_80_percent_smotetomek_data_0.9931751047909485
# Saving 80 percent data set batch used to train the model 3 out of 10
# Saving x_batch_D1_for_model_3_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_3_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_4_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_10_batch_size_80_percent_smotetomek_data_0.9939062519486882
# Saving 80 percent data set batch used to train the model 4 out of 10
# Saving x_batch_D1_for_model_4_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_4_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_5_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_10_batch_size_80_percent_smotetomek_data_0.9945147534868702
# Saving 80 percent data set batch used to train the model 5 out of 10
# Saving x_batch_D1_for_model_5_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_5_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_6_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_10_batch_size_80_percent_smotetomek_data_0.9934117968913331
# Saving 80 percent data set batch used to train the model 6 out of 10
# Saving x_batch_D1_for_model_6_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_6_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_7_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_10_batch_size_80_percent_smotetomek_data_0.9939909394539074
# Saving 80 percent data set batch used to train the model 7 out of 10
# Saving x_batch_D1_for_model_7_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_7_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_8_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_8_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_8_of_10_batch_size_80_percent_smotetomek_data_0.9943183175891832
# Saving 80 percent data set batch used to train the model 8 out of 10
# Saving x_batch_D1_for_model_8_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_8_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_9_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_9_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_9_of_10_batch_size_80_percent_smotetomek_data_0.9943319262010502
# Saving 80 percent data set batch used to train the model 9 out of 10
# Saving x_batch_D1_for_model_9_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_9_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_10_of_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_model_10_of_10_batch_size_80_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_10_of_10_batch_size_80_percent_smotetomek_data_0.9943023314861629
# Saving 80 percent data set batch used to train the model 10 out of 10
# Saving x_batch_D1_for_model_10_of_10_batch_size_80_percent_smotetomek_data
# Saving y_batch_D1_for_model_10_of_10_batch_size_80_percent_smotetomek_data
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# CPU times: user 30min 59s, sys: 25.5 s, total: 31min 25s
# Wall time: 9h 12min 34s

# %% [markdown]
# **Take all these models batch wise meaning taking them and run D2 into them to get the result.**

# %%
np.save("input_list_smotetomek_data",input_list_smotetomek_data)
np.save("param_list_smotetomek_data",param_list_smotetomek_data)
np.save("score_list_smotetomek_data",score_list_smotetomek_data)

# %%
input_list_smotetomek_data=np.load("input_list_smotetomek_data.npy",allow_pickle=True)
param_list_smotetomek_data=np.load("param_list_smotetomek_data.npy",allow_pickle=True)
score_list_smotetomek_data=np.load("score_list_smotetomek_data.npy",allow_pickle=True)

# %% [markdown]
# **Selecting only the top 10 dataset and model config to train my Meta model that gives me the highest cv score.**

# %%
# %%time
counter=0
average=[]
models_n_batches=[]
for m_x in model_count:
    for b_x in batch_size:
        b_x=int(b_x*100)
        xxx=0
        val=0
        print("model_count : ",m_x)
        print("batch_size : ",b_x)
        for i in range(0,m_x):
            xxx=xxx+score_list_smotetomek_data[counter]
            counter=counter+1
            val=val+1
        print("number of models "+str(m_x)+", batch_size in "+str(b_x),"average : ",xxx/val)
        models_n_batches.append("number of models "+str(m_x)+", batch_size in "+str(b_x))
        average.append(xxx/val)
        print("+++++++++++++++++++++++++++++++++++")
# Out:
# model_count :  5
# batch_size :  30
# number of models 5, batch_size in 30 average :  0.9898735063453581
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  40
# number of models 5, batch_size in 40 average :  0.9917268449922301
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  50
# number of models 5, batch_size in 50 average :  0.9920221696733952
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  60
# number of models 5, batch_size in 60 average :  0.9927832781439918
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  70
# number of models 5, batch_size in 70 average :  0.9937409517326514
# +++++++++++++++++++++++++++++++++++
# model_count :  5
# batch_size :  80
# number of models 5, batch_size in 80 average :  0.9942717111133911
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  30
# number of models 6, batch_size in 30 average :  0.989410478286497
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  40
# number of models 6, batch_size in 40 average :  0.9912716934821515
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  50
# number of models 6, batch_size in 50 average :  0.9923250426602089
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  60
# number of models 6, batch_size in 60 average :  0.9931504588325529
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  70
# number of models 6, batch_size in 70 average :  0.9935738361774086
# +++++++++++++++++++++++++++++++++++
# model_count :  6
# batch_size :  80
# number of models 6, batch_size in 80 average :  0.9942122576175135
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  30
# number of models 7, batch_size in 30 average :  0.9900590977511896
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  40
# number of models 7, batch_size in 40 average :  0.9913426396381144
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  50
# number of models 7, batch_size in 50 average :  0.9921642927245633
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  60
# number of models 7, batch_size in 60 average :  0.993101354962432
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  70
# number of models 7, batch_size in 70 average :  0.9938732083285062
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  80
# number of models 7, batch_size in 80 average :  0.9942800840509562
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  30
# number of models 8, batch_size in 30 average :  0.9902121488826706
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  40
# number of models 8, batch_size in 40 average :  0.9917963524148562
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  50
# number of models 8, batch_size in 50 average :  0.9925405902189356
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  60
# number of models 8, batch_size in 60 average :  0.9927500130262291
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  70
# number of models 8, batch_size in 70 average :  0.9939201191899443
# +++++++++++++++++++++++++++++++++++
# model_count :  8
# batch_size :  80
# number of models 8, batch_size in 80 average :  0.9941870010262508
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  30
# number of models 9, batch_size in 30 average :  0.9896785149004113
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  40
# number of models 9, batch_size in 40 average :  0.9914069166853905
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  50
# number of models 9, batch_size in 50 average :  0.9924789839231081
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  60
# number of models 9, batch_size in 60 average :  0.9934259300290358
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  70
# number of models 9, batch_size in 70 average :  0.9937757813419767
# +++++++++++++++++++++++++++++++++++
# model_count :  9
# batch_size :  80
# number of models 9, batch_size in 80 average :  0.9940909828110454
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  30
# number of models 10, batch_size in 30 average :  0.9902890218822377
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  40
# number of models 10, batch_size in 40 average :  0.9915045226383885
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  50
# number of models 10, batch_size in 50 average :  0.9919707614611998
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  60
# number of models 10, batch_size in 60 average :  0.9930590422288356
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  70
# number of models 10, batch_size in 70 average :  0.9937719142009319
# +++++++++++++++++++++++++++++++++++
# model_count :  10
# batch_size :  80
# number of models 10, batch_size in 80 average :  0.9939756690149393
# +++++++++++++++++++++++++++++++++++
# CPU times: user 31.2 ms, sys: 19.7 ms, total: 51 ms
# Wall time: 37.7 ms

# %% [markdown]
# **Selecting the top 10 train scores and model configurations.**

# %%
np.sort(average)[::-1][:10]
# Out:
# array([0.99428008, 0.99427171, 0.99421226, 0.994187  , 0.99409098,
#        0.99397567, 0.99392012, 0.99387321, 0.99377578, 0.99377191])

# %%
np.array(models_n_batches)[np.argsort(average)[::-1][:10]]
# Out:
# array(['number of models 7, batch_size in 80',
#        'number of models 5, batch_size in 80',
#        'number of models 6, batch_size in 80',
#        'number of models 8, batch_size in 80',
#        'number of models 9, batch_size in 80',
#        'number of models 10, batch_size in 80',
#        'number of models 8, batch_size in 70',
#        'number of models 7, batch_size in 70',
#        'number of models 9, batch_size in 70',
#        'number of models 10, batch_size in 70'], dtype='<U37')

# %% [markdown]
# **Now I pass the D2 set to each of these model_count models(hyper parameter), now I will get that many predictions for D2, from each of these models, which in turn will become my new dataset.**

# %%
model_count=[7,5,6,8,9,10,8,7,9,10]
batch_size=[80,80,80,80,80,80,70,70,70,70]

# %%
data_type="smotetomek_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    xxx=pd.DataFrame()

    for i in range(1,m_x+1):

        #Load the model.
        pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                             'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Make the prediction.
        y_pred=model.predict(D2_smotetomek_x_train)

        #Assign the prediction to a new column in the current dataframe
        xxx[str(i)]=y_pred
        del model

    xxx.to_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
# Out:
# number of models 7, batch_size in 80
# number of models 5, batch_size in 80
# number of models 6, batch_size in 80
# number of models 8, batch_size in 80
# number of models 9, batch_size in 80
# number of models 10, batch_size in 80
# number of models 8, batch_size in 70
# number of models 7, batch_size in 70
# number of models 9, batch_size in 70
# number of models 10, batch_size in 70

# %% [markdown]
# **Now, this new dataset that I have, and the D2_Y values that I have ,I  will train new <u>meta model</u>,
# with 10 configurations. and select the top meta model.**

# %%
Meta_Model_input_list_smotetomek_data=[]
Meta_Model_param_list_smotetomek_data=[]
Meta_Model_score_list_smotetomek_data=[]
data_type="smotetomek_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))
    x_data=pd.read_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    y_data=D2_smotetomek_y_train.copy()
    param,score=train_the_meta_model(x_data,y_data,data_type,m_x,b_x)

    Meta_Model_input_list_smotetomek_data.append("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    Meta_Model_param_list_smotetomek_data.append(param)
    Meta_Model_score_list_smotetomek_data.append(score)
        
np.save("Meta_Model_input_list_smotetomek_data.npy",Meta_Model_input_list_smotetomek_data)
np.save("Meta_Model_param_list_smotetomek_data.npy",Meta_Model_param_list_smotetomek_data)
np.save("Meta_Model_score_list_smotetomek_data.npy",Meta_Model_score_list_smotetomek_data)
Meta_Model_input_list_smotetomek_data=np.load("Meta_Model_input_list_smotetomek_data.npy",allow_pickle=True)
Meta_Model_param_list_smotetomek_data=np.load("Meta_Model_param_list_smotetomek_data.npy",allow_pickle=True)
Meta_Model_score_list_smotetomek_data=np.load("Meta_Model_score_list_smotetomek_data.npy",allow_pickle=True)
# Out:
# number of models 7, batch_size in 80
# Saving Meta_model_7_batch_size_80_percent_smotetomek_data
# Saving best_params_for_Meta_model_7_batch_size_80_percent_smotetomek_data_{'max_depth': 4, 'min_samples_split': 50}
# Saving best_scores_for_Meta_model_7_batch_size_80_percent_smotetomek_data_0.9975844143538568
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 5, batch_size in 80
# Saving Meta_model_5_batch_size_80_percent_smotetomek_data
# Saving best_params_for_Meta_model_5_batch_size_80_percent_smotetomek_data_{'max_depth': 4, 'min_samples_split': 50}
# Saving best_scores_for_Meta_model_5_batch_size_80_percent_smotetomek_data_0.9962059755851845
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 6, batch_size in 80
# Saving Meta_model_6_batch_size_80_percent_smotetomek_data
# Saving best_params_for_Meta_model_6_batch_size_80_percent_smotetomek_data_{'max_depth': 4, 'min_samples_split': 50}
# Saving best_scores_for_Meta_model_6_batch_size_80_percent_smotetomek_data_0.9968299122878725
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 8, batch_size in 80
# Saving Meta_model_8_batch_size_80_percent_smotetomek_data
# Saving best_params_for_Meta_model_8_batch_size_80_percent_smotetomek_data_{'max_depth': 4, 'min_samples_split': 40}
# Saving best_scores_for_Meta_model_8_batch_size_80_percent_smotetomek_data_0.9972907019824533
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 9, batch_size in 80
# Saving Meta_model_9_batch_size_80_percent_smotetomek_data
# Saving best_params_for_Meta_model_9_batch_size_80_percent_smotetomek_data_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_9_batch_size_80_percent_smotetomek_data_0.9974710977177421
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 10, batch_size in 80
# Saving Meta_model_10_batch_size_80_percent_smotetomek_data
# Saving best_params_for_Meta_model_10_batch_size_80_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_10_batch_size_80_percent_smotetomek_data_0.99703040549712
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 8, batch_size in 70
# Saving Meta_model_8_batch_size_70_percent_smotetomek_data
# Saving best_params_for_Meta_model_8_batch_size_70_percent_smotetomek_data_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_8_batch_size_70_percent_smotetomek_data_0.9970995799642676
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 70
# Saving Meta_model_7_batch_size_70_percent_smotetomek_data
# Saving best_params_for_Meta_model_7_batch_size_70_percent_smotetomek_data_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_70_percent_smotetomek_data_0.9969763432116518
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 9, batch_size in 70
# Saving Meta_model_9_batch_size_70_percent_smotetomek_data
# Saving best_params_for_Meta_model_9_batch_size_70_percent_smotetomek_data_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_9_batch_size_70_percent_smotetomek_data_0.9969407855416328
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 10, batch_size in 70
# Saving Meta_model_10_batch_size_70_percent_smotetomek_data
# Saving best_params_for_Meta_model_10_batch_size_70_percent_smotetomek_data_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_10_batch_size_70_percent_smotetomek_data_0.9974372949319698
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# **Selecting the top Meta Model with the best CV scores and model configurations on which the main test data.**

# %%
np.sort(Meta_Model_score_list_smotetomek_data)[::-1][0]
# Out:
# 0.9975844143538568

# %%
Meta_Model_input_list_smotetomek_data[np.argsort(Meta_Model_score_list_smotetomek_data)[::-1][0]]
# Out:
# 'Meta_model_7_batch_size_80_percent_smotetomek_data'

# %%
Meta_Model_param_list_smotetomek_data[np.argsort(Meta_Model_score_list_smotetomek_data)[::-1][0]]
# Out:
# {'max_depth': 4, 'min_samples_split': 50}

# %%
model_count=[7]
batch_size=[80]
for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))
# Out:
# number of models 7, batch_size in 80

# %% [markdown]
# **Passing the test set that I have, to each of the base models with configurations with top 10 scores so that I get "model_count" predictions.**

# %%
model_count=[7,5,6,8,9,10,8,7,9,10]
batch_size=[80,80,80,80,80,80,70,70,70,70]

# %%
data_type="smotetomek_data"
for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    xxx=pd.DataFrame()

    for i in range(1,m_x+1):

        #Load the model.
        pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                             str(data_type)+".pickle",'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Make the prediction.
        y_pred=model.predict(new_standard_test_smotetomek_all_features_df)

        #Assign the prediction to a new column in the current dataframe
        xxx[str(i)]=y_pred
        del model

    xxx.to_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
# Out:
# number of models 7, batch_size in 80
# number of models 5, batch_size in 80
# number of models 6, batch_size in 80
# number of models 8, batch_size in 80
# number of models 9, batch_size in 80
# number of models 10, batch_size in 80
# number of models 8, batch_size in 70
# number of models 7, batch_size in 70
# number of models 9, batch_size in 70
# number of models 10, batch_size in 70

# %% [markdown]
# **Now I pass this new dataset and pass it to the meta_model to get the final prediction.**

# %%
model_count=[7]
batch_size=[80]

# %%
data_type="smotetomek_data"

for m_x,b_x in zip(model_count,batch_size):
    print("number of models "+str(m_x)+", batch_size in "+str(b_x))

    #Load the model.
    pickle_object = open("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                         'rb')
    model = pickle.load(pickle_object)
    pickle_object.close()

    #Load the data.
    x_test=pd.read_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
    y_test=y_test_smotetomek_all_features.copy()

    #Make the prediction.
    y_pred=model.predict(x_test)

    #Now try and figure out the F2 Score.
    f2_score=fbeta_score(y_test, y_pred, pos_label=1.0, beta=2)
    print("f2_score : ",f2_score)
    print("confusion_matrix : \n",confusion_matrix(y_test, y_pred))
# Out:
# number of models 7, batch_size in 80
# f2_score :  0.8737864077669903
# confusion_matrix :
#  Predicted    0.0  1.0
# True
# 0.0        11750   50
# 1.0           20  180

# %% [markdown]
# <h3>custom_ensemble function</h3>

# %%
def custom_ensemble(x_train,y_train,x_test, n_estimators):
    

    """x_train = Train data
       y_train = Labels for train data
       x_test = The test dataset
       n_estimators = number of base models.
    The function should do everything from dividing X_train to D1 and D2 to predictions from meta model.
    This function returns the predictions for X_test."""

    #Splitting the train set into D1 and D2(50-50)
    D1_x_train, D2_x_train, D1_y_train, D2_y_train = \
    train_test_split(x_train, y_train, test_size=0.50, stratify=y_train)  

    #Now from this D1 do sampling with replacement to create d1,d2,d3....dk(k samples)

    #I will create model_count samples(hyperparameter). Each sample containing randomly (with replacement), 
    #batch_size% of the data(hyperparameter).

    model_count=[n_estimators]
    batch_size=[0.3,0.4,0.5,0.6,0.7,0.8]    

    data_type="function"
    input_list_data=[]
    param_list_data=[]
    score_list_data=[]
    for m_x in model_count:
        for b_x in batch_size:
            for i in range(1,m_x+1):
                param,score=train_the_decision_trees(D1_x_train,D1_y_train,data_type,i,m_x,b_x)
                input_list_data.append("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_"+data_type)
                param_list_data.append(param)
                score_list_data.append(score)

    #Take all these models batch wise meaning taking them and run D2 into them to get the result.  

    np.save("input_list_data",input_list_data)
    np.save("param_list_data",param_list_data)
    np.save("score_list_data",score_list_data)

    input_list_data=np.load("input_list_data.npy",allow_pickle=True)
    param_list_data=np.load("param_list_data.npy",allow_pickle=True)
    score_list_data=np.load("score_list_data.npy",allow_pickle=True)

    #Selecting only the top 10 dataset and model config to train my Meta model that gives me the highest cv score.
    counter=0
    average=[]
    models=[]
    batches=[]
    for m_x in model_count:
        for b_x in batch_size:
            b_x=int(b_x*100)
            xxx=0
            val=0
            print("model_count : ",m_x)
            print("batch_size : ",b_x)
            for i in range(0,m_x):
                xxx=xxx+score_list_data[counter]
                counter=counter+1
                val=val+1
            print("number of models "+str(m_x)+", batch_size in "+str(b_x),"average : ",xxx/val)
            models.append(int(m_x))
            batches.append(int(b_x))
            average.append(xxx/val)
            print("+++++++++++++++++++++++++++++++++++")

    #Selecting the top 10 train scores and model configurations.
    print("Top 10 Averages :", np.sort(average)[::-1][:10])


    model_count=list(np.array(models)[np.argsort(average)[::-1][:10]])
    batch_size=list(np.array(batches)[np.argsort(average)[::-1][:10]])


    #Now I pass the D2 set to each of these model_count models(hyper parameter), 
    #now I will get that many predictions for D2, from each of these models, which in turn will 
    #become my new dataset.    
    for m_x,b_x in zip(model_count,batch_size):
        print("number of models "+str(m_x)+", batch_size in "+str(b_x))

        xxx=pd.DataFrame()

        for i in range(1,m_x+1):

            #Load the model.
            pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                                 'rb')
            model = pickle.load(pickle_object)
            pickle_object.close()

            #Make the prediction.
            y_pred=model.predict(D2_x_train)

            #Assign the prediction to a new column in the current dataframe
            xxx[str(i)]=y_pred
            del model

        xxx.to_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))


    #Now, this new dataset that I have, and the D2_Y values that I have ,I  will train new meta model, with 
    #10 configurations. and select the top meta model.
    Meta_Model_input_list_data=[]
    Meta_Model_param_list_data=[]
    Meta_Model_score_list_data=[]

    for m_x,b_x in zip(model_count,batch_size):
        print("number of models "+str(m_x)+", batch_size in "+str(b_x))
        x_data=pd.read_pickle("data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
        y_data=D2_y_train.copy()
        param,score=train_the_meta_model(x_data,y_data,data_type,m_x,b_x)

        Meta_Model_input_list_data.append("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))
        Meta_Model_param_list_data.append(param)
        Meta_Model_score_list_data.append(score)

    np.save("Meta_Model_input_list_data.npy",Meta_Model_input_list_data)
    np.save("Meta_Model_param_list_data.npy",Meta_Model_param_list_data)
    np.save("Meta_Model_score_list_data.npy",Meta_Model_score_list_data)

    Meta_Model_input_list_data=np.load("Meta_Model_input_list_data.npy",allow_pickle=True)
    Meta_Model_param_list_data=np.load("Meta_Model_param_list_data.npy",allow_pickle=True)
    Meta_Model_score_list_data=np.load("Meta_Model_score_list_data.npy",allow_pickle=True)

    #Selecting the top Meta Model with the best CV scores and model configurations on which the main test data.\

    print("Best Meta Model score : ",np.sort(Meta_Model_score_list_data)[::-1][0])

    print("Best Meta Model input : ",Meta_Model_input_list_data[np.argsort(Meta_Model_score_list_data)[::-1][0]])

    print("Best Meta Model params : ",Meta_Model_param_list_data[np.argsort(Meta_Model_score_list_data)[::-1][0]])

    #Passing the test set that I have, to each of the base models with configurations with top 10 scores so that I get "model_count" predictions.

    for m_x,b_x in zip(model_count,batch_size):
        print("number of models "+str(m_x)+", batch_size in "+str(b_x))

        xxx=pd.DataFrame()

        for i in range(1,m_x+1):

            #Load the model.
            pickle_object = open("DT_model_"+str(i)+"_of_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+\
                                 str(data_type)+".pickle",'rb')
            model = pickle.load(pickle_object)
            pickle_object.close()

            #Make the prediction.
            y_pred=model.predict(x_test)

            #Assign the prediction to a new column in the current dataframe
            xxx[str(i)]=y_pred
            del model

        xxx.to_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))

    batch_size=[int(Meta_Model_input_list_data[np.argsort(Meta_Model_score_list_data)[::-1][0]].split("_")[5])]
    model_count=[int(Meta_Model_input_list_data[np.argsort(Meta_Model_score_list_data)[::-1][0]].split("_")[2])]

    #Now I pass this new dataset and pass it to the meta_model to get the final prediction.

    for m_x,b_x in zip(model_count,batch_size):
        print("number of models "+str(m_x)+", batch_size in "+str(b_x))

        #Load the model.
        pickle_object = open("Meta_model_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type)+".pickle",
                             'rb')
        model = pickle.load(pickle_object)
        pickle_object.close()

        #Load the data.
        x_test=pd.read_pickle("test_data_model_count_"+str(m_x)+"_batch_size_"+str(b_x)+"_percent_"+str(data_type))

        #Make the prediction.
        y_pred=model.predict(x_test)

    return y_pred

# %%
y_pred = custom_ensemble(new_x_smotetomek_df,
                         y_smotetomek,
                         new_standard_test_smotetomek_all_features_df,
                         7)
# Out:
# Saving DT_model_1_of_7_batch_size_30_percent_function
# Saving best_params_for_model_1_of_7_batch_size_30_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_7_batch_size_30_percent_function_0.9908195076103652
# Saving 30 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_1_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_30_percent_function
# Saving best_params_for_model_2_of_7_batch_size_30_percent_function_{'max_depth': 6, 'min_samples_split': 20}
# Saving best_scores_for_model_2_of_7_batch_size_30_percent_function_0.9886914726438663
# Saving 30 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_2_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_30_percent_function
# Saving best_params_for_model_3_of_7_batch_size_30_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_30_percent_function_0.9913957498263045
# Saving 30 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_3_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_30_percent_function
# Saving best_params_for_model_4_of_7_batch_size_30_percent_function_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_7_batch_size_30_percent_function_0.9881830063466704
# Saving 30 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_4_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_30_percent_function
# Saving best_params_for_model_5_of_7_batch_size_30_percent_function_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_7_batch_size_30_percent_function_0.9902350977246946
# Saving 30 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_5_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_30_percent_function
# Saving best_params_for_model_6_of_7_batch_size_30_percent_function_{'max_depth': 6, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_7_batch_size_30_percent_function_0.9897921512396598
# Saving 30 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_6_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_30_percent_function
# Saving best_params_for_model_7_of_7_batch_size_30_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_30_percent_function_0.9883454714269636
# Saving 30 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_30_percent_function
# Saving y_batch_D1_for_model_7_of_7_batch_size_30_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_40_percent_function
# Saving best_params_for_model_1_of_7_batch_size_40_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_7_batch_size_40_percent_function_0.9900478520139397
# Saving 40 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_1_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_40_percent_function
# Saving best_params_for_model_2_of_7_batch_size_40_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_7_batch_size_40_percent_function_0.9902148577045734
# Saving 40 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_2_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_40_percent_function
# Saving best_params_for_model_3_of_7_batch_size_40_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_40_percent_function_0.9929291815081122
# Saving 40 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_3_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_40_percent_function
# Saving best_params_for_model_4_of_7_batch_size_40_percent_function_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_4_of_7_batch_size_40_percent_function_0.9921056839247836
# Saving 40 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_4_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_40_percent_function
# Saving best_params_for_model_5_of_7_batch_size_40_percent_function_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_7_batch_size_40_percent_function_0.9908616019741823
# Saving 40 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_5_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_40_percent_function
# Saving best_params_for_model_6_of_7_batch_size_40_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_7_batch_size_40_percent_function_0.9915140210720363
# Saving 40 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_6_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_40_percent_function
# Saving best_params_for_model_7_of_7_batch_size_40_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_40_percent_function_0.9923695232922357
# Saving 40 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_40_percent_function
# Saving y_batch_D1_for_model_7_of_7_batch_size_40_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_50_percent_function
# Saving best_params_for_model_1_of_7_batch_size_50_percent_function_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_7_batch_size_50_percent_function_0.992938052464315
# Saving 50 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_1_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_50_percent_function
# Saving best_params_for_model_2_of_7_batch_size_50_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_7_batch_size_50_percent_function_0.9939740975959263
# Saving 50 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_2_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_50_percent_function
# Saving best_params_for_model_3_of_7_batch_size_50_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_50_percent_function_0.9922415395202215
# Saving 50 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_3_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_50_percent_function
# Saving best_params_for_model_4_of_7_batch_size_50_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_7_batch_size_50_percent_function_0.9927364119842709
# Saving 50 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_4_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_50_percent_function
# Saving best_params_for_model_5_of_7_batch_size_50_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_7_batch_size_50_percent_function_0.9928955553693368
# Saving 50 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_5_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_50_percent_function
# Saving best_params_for_model_6_of_7_batch_size_50_percent_function_{'max_depth': 8, 'min_samples_split': 10}
# Saving best_scores_for_model_6_of_7_batch_size_50_percent_function_0.9922273754139873
# Saving 50 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_6_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_50_percent_function
# Saving best_params_for_model_7_of_7_batch_size_50_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_50_percent_function_0.9926190584593378
# Saving 50 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_50_percent_function
# Saving y_batch_D1_for_model_7_of_7_batch_size_50_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_60_percent_function
# Saving best_params_for_model_1_of_7_batch_size_60_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_7_batch_size_60_percent_function_0.992438418344633
# Saving 60 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_1_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_60_percent_function
# Saving best_params_for_model_2_of_7_batch_size_60_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_7_batch_size_60_percent_function_0.993946279355273
# Saving 60 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_2_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_60_percent_function
# Saving best_params_for_model_3_of_7_batch_size_60_percent_function_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_3_of_7_batch_size_60_percent_function_0.9929322729755979
# Saving 60 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_3_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_60_percent_function
# Saving best_params_for_model_4_of_7_batch_size_60_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_7_batch_size_60_percent_function_0.9926293559162881
# Saving 60 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_4_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_60_percent_function
# Saving best_params_for_model_5_of_7_batch_size_60_percent_function_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_7_batch_size_60_percent_function_0.9931194443265884
# Saving 60 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_5_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_60_percent_function
# Saving best_params_for_model_6_of_7_batch_size_60_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_7_batch_size_60_percent_function_0.9934026528373924
# Saving 60 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_6_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_60_percent_function
# Saving best_params_for_model_7_of_7_batch_size_60_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_60_percent_function_0.9930813484455194
# Saving 60 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_60_percent_function
# Saving y_batch_D1_for_model_7_of_7_batch_size_60_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_70_percent_function
# Saving best_params_for_model_1_of_7_batch_size_70_percent_function_{'max_depth': 10, 'min_samples_split': 10}
# Saving best_scores_for_model_1_of_7_batch_size_70_percent_function_0.993086456979331
# Saving 70 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_1_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_70_percent_function
# Saving best_params_for_model_2_of_7_batch_size_70_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_2_of_7_batch_size_70_percent_function_0.9949206689447312
# Saving 70 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_2_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_70_percent_function
# Saving best_params_for_model_3_of_7_batch_size_70_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_70_percent_function_0.9938449366470368
# Saving 70 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_3_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_70_percent_function
# Saving best_params_for_model_4_of_7_batch_size_70_percent_function_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_7_batch_size_70_percent_function_0.9935384289693315
# Saving 70 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_4_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_70_percent_function
# Saving best_params_for_model_5_of_7_batch_size_70_percent_function_{'max_depth': 9, 'min_samples_split': 10}
# Saving best_scores_for_model_5_of_7_batch_size_70_percent_function_0.9932024620805351
# Saving 70 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_5_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_70_percent_function
# Saving best_params_for_model_6_of_7_batch_size_70_percent_function_{'max_depth': 14, 'min_samples_split': 10}
# Saving best_scores_for_model_6_of_7_batch_size_70_percent_function_0.9939078217055524
# Saving 70 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_6_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_70_percent_function
# Saving best_params_for_model_7_of_7_batch_size_70_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_70_percent_function_0.9929425949618386
# Saving 70 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_70_percent_function
# Saving y_batch_D1_for_model_7_of_7_batch_size_70_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_1_of_7_batch_size_80_percent_function
# Saving best_params_for_model_1_of_7_batch_size_80_percent_function_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_1_of_7_batch_size_80_percent_function_0.9943041332570619
# Saving 80 percent data set batch used to train the model 1 out of 7
# Saving x_batch_D1_for_model_1_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_1_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_2_of_7_batch_size_80_percent_function
# Saving best_params_for_model_2_of_7_batch_size_80_percent_function_{'max_depth': 12, 'min_samples_split': 10}
# Saving best_scores_for_model_2_of_7_batch_size_80_percent_function_0.9939912729169581
# Saving 80 percent data set batch used to train the model 2 out of 7
# Saving x_batch_D1_for_model_2_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_2_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_3_of_7_batch_size_80_percent_function
# Saving best_params_for_model_3_of_7_batch_size_80_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_model_3_of_7_batch_size_80_percent_function_0.9938679579690792
# Saving 80 percent data set batch used to train the model 3 out of 7
# Saving x_batch_D1_for_model_3_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_3_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_4_of_7_batch_size_80_percent_function
# Saving best_params_for_model_4_of_7_batch_size_80_percent_function_{'max_depth': 12, 'min_samples_split': 2}
# Saving best_scores_for_model_4_of_7_batch_size_80_percent_function_0.9939645942705221
# Saving 80 percent data set batch used to train the model 4 out of 7
# Saving x_batch_D1_for_model_4_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_4_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_5_of_7_batch_size_80_percent_function
# Saving best_params_for_model_5_of_7_batch_size_80_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_model_5_of_7_batch_size_80_percent_function_0.9935856993529528
# Saving 80 percent data set batch used to train the model 5 out of 7
# Saving x_batch_D1_for_model_5_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_5_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_6_of_7_batch_size_80_percent_function
# Saving best_params_for_model_6_of_7_batch_size_80_percent_function_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_model_6_of_7_batch_size_80_percent_function_0.9941358213243097
# Saving 80 percent data set batch used to train the model 6 out of 7
# Saving x_batch_D1_for_model_6_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_6_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Saving DT_model_7_of_7_batch_size_80_percent_function
# Saving best_params_for_model_7_of_7_batch_size_80_percent_function_{'max_depth': 14, 'min_samples_split': 2}
# Saving best_scores_for_model_7_of_7_batch_size_80_percent_function_0.9946274435373056
# Saving 80 percent data set batch used to train the model 7 out of 7
# Saving x_batch_D1_for_model_7_of_7_batch_size_80_percent_function
# Saving y_batch_D1_for_model_7_of_7_batch_size_80_percent_function
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  30
# number of models 7, batch_size in 30 average :  0.9896374938312178
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  40
# number of models 7, batch_size in 40 average :  0.9914346744985518
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  50
# number of models 7, batch_size in 50 average :  0.9928045844010567
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  60
# number of models 7, batch_size in 60 average :  0.9930785388858989
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  70
# number of models 7, batch_size in 70 average :  0.9936347671840509
# +++++++++++++++++++++++++++++++++++
# model_count :  7
# batch_size :  80
# number of models 7, batch_size in 80 average :  0.9940681318040271
# +++++++++++++++++++++++++++++++++++
# Top 10 Averages : [0.99406813 0.99363477 0.99307854 0.99280458 0.99143467 0.98963749]
# number of models 7, batch_size in 80
# number of models 7, batch_size in 70
# number of models 7, batch_size in 60
# number of models 7, batch_size in 50
# number of models 7, batch_size in 40
# number of models 7, batch_size in 30
# number of models 7, batch_size in 80
# Saving Meta_model_7_batch_size_80_percent_function
# Saving best_params_for_Meta_model_7_batch_size_80_percent_function_{'max_depth': 4, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_80_percent_function_0.9965802963069059
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 70
# Saving Meta_model_7_batch_size_70_percent_function
# Saving best_params_for_Meta_model_7_batch_size_70_percent_function_{'max_depth': 6, 'min_samples_split': 40}
# Saving best_scores_for_Meta_model_7_batch_size_70_percent_function_0.9970203167245681
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 60
# Saving Meta_model_7_batch_size_60_percent_function
# Saving best_params_for_Meta_model_7_batch_size_60_percent_function_{'max_depth': 17, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_60_percent_function_0.9971331901045242
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 50
# Saving Meta_model_7_batch_size_50_percent_function
# Saving best_params_for_Meta_model_7_batch_size_50_percent_function_{'max_depth': 8, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_50_percent_function_0.9964906660039432
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 40
# Saving Meta_model_7_batch_size_40_percent_function
# Saving best_params_for_Meta_model_7_batch_size_40_percent_function_{'max_depth': 10, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_40_percent_function_0.9962642601594351
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# number of models 7, batch_size in 30
# Saving Meta_model_7_batch_size_30_percent_function
# Saving best_params_for_Meta_model_7_batch_size_30_percent_function_{'max_depth': 9, 'min_samples_split': 2}
# Saving best_scores_for_Meta_model_7_batch_size_30_percent_function_0.995182504950623
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Best Meta Model score :  0.9971331901045242
# Best Meta Model input :  Meta_model_7_batch_size_60_percent_function
# Best Meta Model params :  {'max_depth': 17, 'min_samples_split': 2}
# number of models 7, batch_size in 80
# number of models 7, batch_size in 70
# number of models 7, batch_size in 60
# number of models 7, batch_size in 50
# number of models 7, batch_size in 40
# number of models 7, batch_size in 30
# number of models 7, batch_size in 60

# %% [markdown]
# ### Comparitive summary of all the models in the Pretty Table

# %%
from prettytable import PrettyTable

x = PrettyTable()
x.field_names = ["Model","Data","Hyperparameters","CV F2 Score","Test F2 Score"]

x.add_row(["GBDT_XGB","Smotetomek_117_Features","{'n_estimators':500,'max_depth':8,'learning_rate':0.1}","0.99944","0.97208"])
x.add_row(["GBDT_XGB","Median_127_Features","{'n_estimators':300,'max_depth':4,'learning_rate':0.3}","0.93954","0.9718"])
x.add_row(["GBDT_AdaBoost","Smotetomek_117_Features","{'n_estimators':1000,'learning_rate':0.7}","0.99935","0.96439"])
x.add_row(["GBDT_XGB","Adasyn_144_Features","{'n_estimators':500,'max_depth':12,'learning_rate':0.05}","0.99626","0.96326"])
x.add_row(["GBDT_AdaBoost","Median_127_Features","{'n_estimators':1000,'learning_rate':0.3}","0.92683","0.94444"])
x.add_row(["RF","Smotetomek_117_Features","{'max_depth':24,'n_estimators':100}","0.99902","0.92899"])
x.add_row(["RF","Median_127_Features","{'max_depth':18,'n_estimators':100}","0.90227","0.91633"])
x.add_row(["GBDT_AdaBoost","Adasyn_144_Features","{'n_estimators':200,'learning_rate':0.5}","0.99401","0.91251"])
x.add_row(["RF","Adasyn_144_Features","{'max_depth':18,'n_estimators':50}","0.99476","0.91216"])
x.add_row(["MLP","Smotetomek_117_Features","200|0.1|300|0.2|400|0.3|500|0.4|600|0.5,relu","0.99969","0.91045"])
x.add_row(["MLP","Adasyn_144_Features","200|0.1|300|0.2|400|0.3|500|0.4|600|0.5,relu","0.99983","0.89552"])
x.add_row(["MLP","Median_127_Features","200|0.1|300|0.2|400|0.3|500|0.4|600|0.5,relu","0.91076","0.89458"])
x.add_row(["Custom","Smotetomek_Batch_size_80%_Features_7","{'max_depth':4,'min_samples_split':50}","0.99758","0.87378"])
x.add_row(["Custom","Adasyn_Batch_size_80%_Features_10","{'max_depth':6,'min_samples_split':2}","0.99782","0.85959"])
x.add_row(["DT","Adasyn_144_Features","{'max_depth':12,'min_samples_split':2}","0.97742","0.85754"])
x.add_row(["DT","Smotetomek_117_Features","{'max_depth':17,'min_samples_split':2}","0.99606","0.8559"])
x.add_row(["DT","Median_127_Features","{'max_depth':12,'min_samples_split':2}","0.85617","0.84722"])
x.add_row(["Custom","Median_Batch_size_80%_Features_9","{'max_depth':9,'min_samples_split':20}","0.84376","0.81755"])
x.add_row(["KNN","Smotetomek_117_Features","{'n_neighbors':11}","0.99437","0.78215"])
x.add_row(["LR_Lib","Median_127_Features","{'C':0.1}","0.78023","0.75929"])
x.add_row(["LR_Lib","Smotetomek_117_Features","{'C':100}","0.96688","0.73955"])
x.add_row(["KNN","Adasyn_144_Features","{'n_neighbors':31}","0.98078","0.70144"])
x.add_row(["LR_SGD_Lib","Median_127_Features","{'alpha':1e-06}","0.69976","0.68452"])
x.add_row(["SVM_SGD","Adasyn_144_Features","{'alpha':0.001}","0.92844","0.68448"])
x.add_row(["SVM_SGD","Median_127_Features","{'alpha':0.0001}","0.63208","0.68448"])
x.add_row(["LR_Lib","Adasyn_144_Features","{'C':100}","0.93735","0.67131"])
x.add_row(["LR_SGD_Lib","Smotetomek_117_Features","{'alpha':0.0001}","0.96295","0.66421"])
x.add_row(["SVM_SGD","Smotetomek_117_Features","{'alpha':0.0001}","0.96382","0.64996"])
x.add_row(["KNN","Median_127_Features","{'n_neighbors':11}","0.59931","0.62633"])
x.add_row(["LR_SGD_Lib","Adasyn_144_Features","{'alpha':1e-05}","0.93024","0.56628"])
print(x)
# Out:
# +---------------+--------------------------------------+----------------------------------------------------------+-------------+---------------+
# |     Model     |                 Data                 |                     Hyperparameters                      | CV F2 Score | Test F2 Score |
# +---------------+--------------------------------------+----------------------------------------------------------+-------------+---------------+
# |    GBDT_XGB   |       Smotetomek_117_Features        |  {'n_estimators':500,'max_depth':8,'learning_rate':0.1}  |   0.99944   |    0.97208    |
# |    GBDT_XGB   |         Median_127_Features          |  {'n_estimators':300,'max_depth':4,'learning_rate':0.3}  |   0.93954   |     0.9718    |
# | GBDT_AdaBoost |       Smotetomek_117_Features        |        {'n_estimators':1000,'learning_rate':0.7}         |   0.99935   |    0.96439    |
# |    GBDT_XGB   |         Adasyn_144_Features          | {'n_estimators':500,'max_depth':12,'learning_rate':0.05} |   0.99626   |    0.96326    |
# | GBDT_AdaBoost |         Median_127_Features          |        {'n_estimators':1000,'learning_rate':0.3}         |   0.92683   |    0.94444    |
# |       RF      |       Smotetomek_117_Features        |           {'max_depth':24,'n_estimators':100}            |   0.99902   |    0.92899    |
# |       RF      |         Median_127_Features          |           {'max_depth':18,'n_estimators':100}            |   0.90227   |    0.91633    |
# | GBDT_AdaBoost |         Adasyn_144_Features          |         {'n_estimators':200,'learning_rate':0.5}         |   0.99401   |    0.91251    |
# |       RF      |         Adasyn_144_Features          |            {'max_depth':18,'n_estimators':50}            |   0.99476   |    0.91216    |
# |      MLP      |       Smotetomek_117_Features        |       200|0.1|300|0.2|400|0.3|500|0.4|600|0.5,relu       |   0.99969   |    0.91045    |
# |      MLP      |         Adasyn_144_Features          |       200|0.1|300|0.2|400|0.3|500|0.4|600|0.5,relu       |   0.99983   |    0.89552    |
# |      MLP      |         Median_127_Features          |       200|0.1|300|0.2|400|0.3|500|0.4|600|0.5,relu       |   0.91076   |    0.89458    |
# |     Custom    | Smotetomek_Batch_size_80%_Features_7 |          {'max_depth':4,'min_samples_split':50}          |   0.99758   |    0.87378    |
# |     Custom    |  Adasyn_Batch_size_80%_Features_10   |          {'max_depth':6,'min_samples_split':2}           |   0.99782   |    0.85959    |
# |       DT      |         Adasyn_144_Features          |          {'max_depth':12,'min_samples_split':2}          |   0.97742   |    0.85754    |
# |       DT      |       Smotetomek_117_Features        |          {'max_depth':17,'min_samples_split':2}          |   0.99606   |     0.8559    |
# |       DT      |         Median_127_Features          |          {'max_depth':12,'min_samples_split':2}          |   0.85617   |    0.84722    |
# |     Custom    |   Median_Batch_size_80%_Features_9   |          {'max_depth':9,'min_samples_split':20}          |   0.84376   |    0.81755    |
# |      KNN      |       Smotetomek_117_Features        |                    {'n_neighbors':11}                    |   0.99437   |    0.78215    |
# |     LR_Lib    |         Median_127_Features          |                        {'C':0.1}                         |   0.78023   |    0.75929    |
# |     LR_Lib    |       Smotetomek_117_Features        |                        {'C':100}                         |   0.96688   |    0.73955    |
# |      KNN      |         Adasyn_144_Features          |                    {'n_neighbors':31}                    |   0.98078   |    0.70144    |
# |   LR_SGD_Lib  |         Median_127_Features          |                     {'alpha':1e-06}                      |   0.69976   |    0.68452    |
# |    SVM_SGD    |         Adasyn_144_Features          |                     {'alpha':0.001}                      |   0.92844   |    0.68448    |
# |    SVM_SGD    |         Median_127_Features          |                     {'alpha':0.0001}                     |   0.63208   |    0.68448    |
# |     LR_Lib    |         Adasyn_144_Features          |                        {'C':100}                         |   0.93735   |    0.67131    |
# |   LR_SGD_Lib  |       Smotetomek_117_Features        |                     {'alpha':0.0001}                     |   0.96295   |    0.66421    |
# |    SVM_SGD    |       Smotetomek_117_Features        |                     {'alpha':0.0001}                     |   0.96382   |    0.64996    |
# |      KNN      |         Median_127_Features          |                    {'n_neighbors':11}                    |   0.59931   |    0.62633    |
# |   LR_SGD_Lib  |         Adasyn_144_Features          |                     {'alpha':1e-05}                      |   0.93024   |    0.56628    |
# +---------------+--------------------------------------+----------------------------------------------------------+-------------+---------------+

# %% [markdown]
# **Conclusion : Here I am getting the best score with smotetomek median data with XGBoost library.<br>
# with cv score as 0.99944 and test score as : 0.97208<br>
# I also tried with other models and libraries.<br>**
